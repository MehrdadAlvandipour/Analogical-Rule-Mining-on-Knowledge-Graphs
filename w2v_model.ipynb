# %% [markdown]
# # Word2vec model
# This is the model from http://vectors.nlpl.eu/repository/#
#
# Need to cite the following paper:
# Fares, Murhaf; Kutuzov, Andrei; Oepen, Stephan & Velldal, Erik (2017). Word vectors, reuse, and replicability: Towards a community repository of large-text resources, In Jörg Tiedemann (ed.), Proceedings of the 21st Nordic Conference on Computational Linguistics, NoDaLiDa, 22-24 May 2017. Linköping University Electronic Press. ISBN 978-91-7685-601-7

# %% [markdown]
# Detailed info about this model is in w2v_data/3/meta.json but to summerize the main points:
#
# - Lemmatizatin is True, i.e. words are catogrized into their different types, e.g. noun, verb, etc. So some examples of word in the vocabulary are 'man_NOUN', 'Aly_PROPN'.
# - vocabulary size is 296630, and dimension is 300
# - Gensim Continuous Skipgram, window size 5
# - English Wikipedia Dump of February 2017

# %% [markdown]
# And you might find the following commands very useful:
# ```
# wiki_w2v.index2word
# wiki_w2v.word_vec
# wiki_w2v.similarity
# wiki_w2v.similar_by_word
# wiki_w2v.similar_by_vector
# ```

# %% [markdown]
# ----

# %%
import gensim.models as w2v       # Word2Vec Library
import pandas as pd
import sys
import numpy as np

# %%
# %pwd
# Out:
# '/Users/mehrdadalvandipour/MyDir/Rule-Mining-on-Embedding-Enriched-KBs'

# %%
wiki_w2v = w2v.KeyedVectors.load_word2vec_format('./w2v_data/3/model.bin', binary=True)

# %%
type(wiki_w2v)
# Out:
# gensim.models.keyedvectors.Word2VecKeyedVectors

# %%
# This chunk finds all types of words in the model
voc = wiki_w2v.index2entity
types = set()

types

for x in voc:
    ind = x.find('_')
    types.add(x[ind+1:])
    
    

types
# Out:
# {'ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'INTJ',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SYM',
#  'VERB',
#  'X'}

# %%
def find_ex_type(t):
    # Assumes variable 'voc' exists which is a list of words in the model
    # Finds exampels from vocabulary that are from the type 't'.
    # 
    col = [];
    t= t.upper()
    if (t in types):
        for x in voc:
            if x.find('_'+ t) > -1:
                col.append(x)
    else:
        print(t + "does not exist in types")
        print(types)
        
    return col

# %%
find_ex_type('ADV') # remove ; to see
# Out:
# ['also_ADV',
#  'later_ADV',
#  'however_ADV',
#  'well_ADV',
#  'still_ADV',
#  'back_ADV',
#  'often_ADV',
#  'even_ADV',
#  'together_ADV',
#  'currently_ADV',
#  'first_ADV',
#  'originally_ADV',
#  'never_ADV',
#  'eventually_ADV',
#  'usually_ADV',
#  'thus_ADV',
#  'away_ADV',
#  'instead_ADV',
#  'soon_ADV',
#  'rather_ADV',
#  'almost_ADV',
#  'approximately_ADV',
#  'sometimes_ADV',
#  'much_ADV',
#  'previously_ADV',
#  'especially_ADV',
#  'generally_ADV',
#  'ever_ADV',
#  'initially_ADV',
#  'finally_ADV',
#  'long_ADV',
#  'already_ADV',
#  'prior_ADV',
#  'far_ADV',
#  'subsequently_ADV',
#  'particularly_ADV',
#  'mostly_ADV',
#  'always_ADV',
#  'south_ADV',
#  'therefore_ADV',
#  'nearly_ADV',
#  'mainly_ADV',
#  'recently_ADV',
#  'yet_ADV',
#  'primarily_ADV',
#  'directly_ADV',
#  'highly_ADV',
#  'immediately_ADV',
#  'shortly_ADV',
#  'quickly_ADV',
#  'formerly_ADV',
#  'typically_ADV',
#  'commonly_ADV',
#  'probably_ADV',
#  'officially_ADV',
#  'actually_ADV',
#  'widely_ADV',
#  'alone_ADV',
#  'largely_ADV',
#  'less_ADV',
#  'respectively_ADV',
#  'early_ADV',
#  'simply_ADV',
#  'longer_ADV',
#  'north_ADV',
#  'twice_ADV',
#  'newly_ADV',
#  'completely_ADV',
#  'forward_ADV',
#  'fully_ADV',
#  'relatively_ADV',
#  'frequently_ADV',
#  'best_ADV',
#  'ultimately_ADV',
#  'specifically_ADV',
#  'quite_ADV',
#  'slightly_ADV',
#  'really_ADV',
#  'enough_ADV',
#  'successfully_ADV',
#  'perhaps_ADV',
#  'earlier_ADV',
#  'heavily_ADV',
#  'entirely_ADV',
#  'notably_ADV',
#  'possibly_ADV',
#  'closely_ADV',
#  'easily_ADV',
#  'additionally_ADV',
#  'regularly_ADV',
#  'meanwhile_ADV',
#  'apart_ADV',
#  'extremely_ADV',
#  'otherwise_ADV',
#  'close_ADV',
#  'afterwards_ADV',
#  'roughly_ADV',
#  'ahead_ADV',
#  'northwest_ADV',
#  'significantly_ADV',
#  'somewhat_ADV',
#  'occasionally_ADV',
#  'formally_ADV',
#  'increasingly_ADV',
#  'better_ADV',
#  'apparently_ADV',
#  'annually_ADV',
#  'strongly_ADV',
#  'normally_ADV',
#  'hence_ADV',
#  'effectively_ADV',
#  'greatly_ADV',
#  'rapidly_ADV',
#  'traditionally_ADV',
#  'gradually_ADV',
#  'similarly_ADV',
#  'thereafter_ADV',
#  'nevertheless_ADV',
#  'indeed_ADV',
#  'abroad_ADV',
#  'ago_ADV',
#  'clearly_ADV',
#  'partly_ADV',
#  'reportedly_ADV',
#  'right_ADV',
#  'furthermore_ADV',
#  'locally_ADV',
#  'publicly_ADV',
#  'internationally_ADV',
#  'elsewhere_ADV',
#  'worldwide_ADV',
#  'partially_ADV',
#  'exclusively_ADV',
#  'rarely_ADV',
#  'else_ADV',
#  'extensively_ADV',
#  'essentially_ADV',
#  'slowly_ADV',
#  'exactly_ADV',
#  'simultaneously_ADV',
#  'literally_ADV',
#  'briefly_ADV',
#  'late_ADV',
#  'namely_ADV',
#  'thereby_ADV',
#  'suddenly_ADV',
#  'consequently_ADV',
#  'aside_ADV',
#  'temporarily_ADV',
#  'historically_ADV',
#  'around_ADV',
#  'merely_ADV',
#  'actively_ADV',
#  'fairly_ADV',
#  'predominantly_ADV',
#  'regardless_ADV',
#  'independently_ADV',
#  'seriously_ADV',
#  'severely_ADV',
#  'virtually_ADV',
#  'unfortunately_ADV',
#  'repeatedly_ADV',
#  'personally_ADV',
#  'allegedly_ADV',
#  'moreover_ADV',
#  'overall_ADV',
#  'nationally_ADV',
#  'deeply_ADV',
#  'permanently_ADV',
#  'privately_ADV',
#  'either_ADV',
#  'though_ADV',
#  'equally_ADV',
#  'automatically_ADV',
#  'potentially_ADV',
#  'certainly_ADV',
#  'constantly_ADV',
#  'properly_ADV',
#  'solely_ADV',
#  'naturally_ADV',
#  'considerably_ADV',
#  'badly_ADV',
#  'necessarily_ADV',
#  'truly_ADV',
#  'politically_ADV',
#  'nearby_ADV',
#  'physically_ADV',
#  'separately_ADV',
#  'second_ADV',
#  'legally_ADV',
#  'consistently_ADV',
#  'poorly_ADV',
#  'forth_ADV',
#  'sometime_ADV',
#  'commercially_ADV',
#  'nonetheless_ADV',
#  'strictly_ADV',
#  'accidentally_ADV',
#  'critically_ADV',
#  'continuously_ADV',
#  'inland_ADV',
#  'jointly_ADV',
#  'likewise_ADV',
#  'totally_ADV',
#  'little_ADV',
#  'forever_ADV',
#  'unsuccessfully_ADV',
#  'openly_ADV',
#  'anywhere_ADV',
#  'likely_ADV',
#  'presumably_ADV',
#  'seemingly_ADV',
#  'faster_ADV',
#  'secretly_ADV',
#  'explicitly_ADV',
#  'narrowly_ADV',
#  'supposedly_ADV',
#  'substantially_ADV',
#  'accordingly_ADV',
#  'straight_ADV',
#  'carefully_ADV',
#  'closer_ADV',
#  'daily_ADV',
#  'specially_ADV',
#  'freely_ADV',
#  'professionally_ADV',
#  'fast_ADV',
#  'ill_ADV',
#  'afterward_ADV',
#  'altogether_ADV',
#  'overseas_ADV',
#  'barely_ADV',
#  'purely_ADV',
#  'somewhere_ADV',
#  'pretty_ADV',
#  'readily_ADV',
#  'dramatically_ADV',
#  'posthumously_ADV',
#  'collectively_ADV',
#  'loosely_ADV',
#  'presently_ADV',
#  'deliberately_ADV',
#  'correctly_ADV',
#  'wholly_ADV',
#  'whenever_ADV',
#  'nowadays_ADV',
#  'sufficiently_ADV',
#  'safely_ADV',
#  'alternatively_ADV',
#  'financially_ADV',
#  'unusually_ADV',
#  'whereby_ADV',
#  'basically_ADV',
#  'sexually_ADV',
#  'steadily_ADV',
#  'technically_ADV',
#  'prominently_ADV',
#  'precisely_ADV',
#  'hard_ADV',
#  'alike_ADV',
#  'individually_ADV',
#  'maybe_ADV',
#  'economically_ADV',
#  'perfectly_ADV',
#  'accurately_ADV',
#  'broadly_ADV',
#  'absolutely_ADV',
#  'arguably_ADV',
#  'socially_ADV',
#  'popularly_ADV',
#  'hardly_ADV',
#  'chiefly_ADV',
#  'differently_ADV',
#  'unanimously_ADV',
#  'positively_ADV',
#  'everywhere_ADV',
#  'obviously_ADV',
#  'westward_ADV',
#  'principally_ADV',
#  'next_ADV',
#  'instantly_ADV',
#  'continually_ADV',
#  'definitely_ADV',
#  'firmly_ADV',
#  'practically_ADV',
#  'mentally_ADV',
#  'globally_ADV',
#  'surprisingly_ADV',
#  'variously_ADV',
#  'promptly_ADV',
#  'deep_ADV',
#  'sharply_ADV',
#  'northward_ADV',
#  'halfway_ADV',
#  'third_ADV',
#  'concurrently_ADV',
#  'short_ADV',
#  'wherein_ADV',
#  'ironically_ADV',
#  'somehow_ADV',
#  'famously_ADV',
#  'east_ADV',
#  'behind_ADV',
#  'internally_ADV',
#  'firstly_ADV',
#  'thoroughly_ADV',
#  'ashore_ADV',
#  'nowhere_ADV',
#  'unexpectedly_ADV',
#  'indirectly_ADV',
#  'eastward_ADV',
#  'anyway_ADV',
#  'anymore_ADV',
#  'p.m._ADV',
#  'intentionally_ADV',
#  'moderately_ADV',
#  'illegally_ADV',
#  'importantly_ADV',
#  'conversely_ADV',
#  'visually_ADV',
#  'digitally_ADV',
#  'farther_ADV',
#  'onward_ADV',
#  'exceptionally_ADV',
#  'backwards_ADV',
#  'periodically_ADV',
#  'voluntarily_ADV',
#  'secondly_ADV',
#  'densely_ADV',
#  'inside_ADV',
#  'comparatively_ADV',
#  'along_ADV',
#  'reluctantly_ADV',
#  'reasonably_ADV',
#  'incorrectly_ADV',
#  'abruptly_ADV',
#  'geographically_ADV',
#  'seldom_ADV',
#  'efficiently_ADV',
#  'negatively_ADV',
#  'backward_ADV',
#  'quietly_ADV',
#  'routinely_ADV',
#  'culturally_ADV',
#  'progressively_ADV',
#  'federally_ADV',
#  'universally_ADV',
#  'uniquely_ADV',
#  'mistakenly_ADV',
#  'genetically_ADV',
#  'informally_ADV',
#  'musically_ADV',
#  'emotionally_ADV',
#  'versa_ADV',
#  'vertically_ADV',
#  'downstream_ADV',
#  'randomly_ADV',
#  'mutually_ADV',
#  'remarkably_ADV',
#  'manually_ADV',
#  'tightly_ADV',
#  'lightly_ADV',
#  'drastically_ADV',
#  'administratively_ADV',
#  'upstream_ADV',
#  'happily_ADV',
#  'wherever_ADV',
#  'a.m._ADV',
#  'indefinitely_ADV',
#  'forcibly_ADV',
#  'colloquially_ADV',
#  'incredibly_ADV',
#  'successively_ADV',
#  'double_ADV',
#  'nominally_ADV',
#  'overly_ADV',
#  'forwards_ADV',
#  'gently_ADV',
#  'outright_ADV',
#  'systematically_ADV',
#  'theoretically_ADV',
#  'ostensibly_ADV',
#  'asleep_ADV',
#  'distinctly_ADV',
#  'evenly_ADV',
#  'northeast_ADV',
#  'falsely_ADV',
#  'fortunately_ADV',
#  'lastly_ADV',
#  'evidently_ADV',
#  'approx_ADV',
#  'overwhelmingly_ADV',
#  'downhill_ADV',
#  'adequately_ADV',
#  'thereof_ADV',
#  'alternately_ADV',
#  'inadvertently_ADV',
#  'fundamentally_ADV',
#  'thence_ADV',
#  'radically_ADV',
#  'centrally_ADV',
#  'desperately_ADV',
#  'undoubtedly_ADV',
#  'environmentally_ADV',
#  'surely_ADV',
#  'since_ADV',
#  'strategically_ADV',
#  'violently_ADV',
#  'inevitably_ADV',
#  'appropriately_ADV',
#  'horizontally_ADV',
#  'last_ADV',
#  'utterly_ADV',
#  'sparsely_ADV',
#  'domestically_ADV',
#  'duly_ADV',
#  'beautifully_ADV',
#  'comfortably_ADV',
#  'offshore_ADV',
#  'fatally_ADV',
#  'northwards_ADV',
#  'favorably_ADV',
#  'inherently_ADV',
#  'finely_ADV',
#  'vastly_ADV',
#  'mortally_ADV',
#  'externally_ADV',
#  'coincidentally_ADV',
#  'backstage_ADV',
#  'remotely_ADV',
#  'peacefully_ADV',
#  'angrily_ADV',
#  'swiftly_ADV',
#  'southward_ADV',
#  'aggressively_ADV',
#  'statewide_ADV',
#  'uniformly_ADV',
#  'erroneously_ADV',
#  'structurally_ADV',
#  'genuinely_ADV',
#  'unofficially_ADV',
#  'markedly_ADV',
#  'no._ADV',
#  'brutally_ADV',
#  'hugely_ADV',
#  'lyrically_ADV',
#  'ideally_ADV',
#  'statistically_ADV',
#  'invariably_ADV',
#  'aground_ADV',
#  'fifth_ADV',
#  "o'clock_ADV",
#  'electrically_ADV',
#  'interestingly_ADV',
#  'ethnically_ADV',
#  'academically_ADV',
#  'dear_ADV',
#  'brightly_ADV',
#  'richly_ADV',
#  'immensely_ADV',
#  'electronically_ADV',
#  'prematurely_ADV',
#  'sporadically_ADV',
#  'racially_ADV',
#  'wrongly_ADV',
#  'vigorously_ADV',
#  'intensely_ADV',
#  'smoothly_ADV',
#  'beforehand_ADV',
#  'indoors_ADV',
#  'noticeably_ADV',
#  'scientifically_ADV',
#  'mechanically_ADV',
#  'spontaneously_ADV',
#  'morally_ADV',
#  'hastily_ADV',
#  'upward_ADV',
#  'seasonally_ADV',
#  'whatsoever_ADV',
#  'sadly_ADV',
#  'expressly_ADV',
#  'fiercely_ADV',
#  'hitherto_ADV',
#  'intermittently_ADV',
#  'outdoors_ADV',
#  'artificially_ADV',
#  'sooner_ADV',
#  'chemically_ADV',
#  'anonymously_ADV',
#  'tentatively_ADV',
#  'lately_ADV',
#  'harder_ADV',
#  'controversially_ADV',
#  'theatrically_ADV',
#  'profoundly_ADV',
#  'decisively_ADV',
#  'regionally_ADV',
#  'home_ADV',
#  'wildly_ADV',
#  'purportedly_ADV',
#  'west_ADV',
#  'reliably_ADV',
#  'mathematically_ADV',
#  'alphabetically_ADV',
#  'underground_ADV',
#  'scarcely_ADV',
#  'steeply_ADV',
#  'southwards_ADV',
#  'romantically_ADV',
#  'overboard_ADV',
#  'selectively_ADV',
#  'experimentally_ADV',
#  'infinitely_ADV',
#  'reputedly_ADV',
#  'therein_ADV',
#  'affectionately_ADV',
#  'visibly_ADV',
#  'incidentally_ADV',
#  'implicitly_ADV',
#  'hopefully_ADV',
#  'weakly_ADV',
#  'upside_ADV',
#  'sixth_ADV',
#  'conventionally_ADV',
#  'notoriously_ADV',
#  'weekly_ADV',
#  'mysteriously_ADV',
#  'adversely_ADV',
#  'aloud_ADV',
#  'massively_ADV',
#  'bitterly_ADV',
#  'laterally_ADV',
#  'dangerously_ADV',
#  'verbally_ADV',
#  'clinically_ADV',
#  'afloat_ADV',
#  'enthusiastically_ADV',
#  'classically_ADV',
#  'side-by-side_ADV',
#  'arbitrarily_ADV',
#  'westwards_ADV',
#  'willingly_ADV',
#  'irrespective_ADV',
#  'consciously_ADV',
#  'excessively_ADV',
#  'consecutively_ADV',
#  'decidedly_ADV',
#  'proudly_ADV',
#  'architecturally_ADV',
#  'functionally_ADV',
#  'unopposed_ADV',
#  'harshly_ADV',
#  'apiece_ADV',
#  'sideways_ADV',
#  'exceedingly_ADV',
#  'definitively_ADV',
#  'interchangeably_ADV',
#  'improperly_ADV',
#  'extraordinarily_ADV',
#  'mildly_ADV',
#  'strangely_ADV',
#  'jokingly_ADV',
#  'enormously_ADV',
#  'medically_ADV',
#  'overtly_ADV',
#  'equivalently_ADV',
#  'militarily_ADV',
#  'forcefully_ADV',
#  'purposely_ADV',
#  'symbolically_ADV',
#  'faithfully_ADV',
#  'dynamically_ADV',
#  'solo_ADV',
#  'orally_ADV',
#  'ordinarily_ADV',
#  'numerically_ADV',
#  'chronologically_ADV',
#  'thinly_ADV',
#  'constitutionally_ADV',
#  'stylistically_ADV',
#  'outwards_ADV',
#  'logically_ADV',
#  'biologically_ADV',
#  'counter_ADV',
#  'vehemently_ADV',
#  'oddly_ADV',
#  'kindly_ADV',
#  'latterly_ADV',
#  'wide_ADV',
#  'brilliantly_ADV',
#  'unintentionally_ADV',
#  'predominately_ADV',
#  'conveniently_ADV',
#  'downward_ADV',
#  'singly_ADV',
#  'technologically_ADV',
#  'loudly_ADV',
#  'exponentially_ADV',
#  'freshly_ADV',
#  'left_ADV',
#  'infrequently_ADV',
#  'characteristically_ADV',
#  'vaguely_ADV',
#  'religiously_ADV',
#  'intellectually_ADV',
#  'aesthetically_ADV',
#  'eagerly_ADV',
#  'warmly_ADV',
#  'superficially_ADV',
#  'preferably_ADV',
#  'favourably_ADV',
#  'democratically_ADV',
#  'luckily_ADV',
#  'spiritually_ADV',
#  'obliquely_ADV',
#  'linearly_ADV',
#  'intimately_ADV',
#  'honestly_ADV',
#  'subtly_ADV',
#  'marginally_ADV',
#  'optionally_ADV',
#  'awake_ADV',
#  'operationally_ADV',
#  'unknowingly_ADV',
#  'diagonally_ADV',
#  'retroactively_ADV',
#  '3rd_ADV',
#  'silently_ADV',
#  'unfairly_ADV',
#  'unilaterally_ADV',
#  'curiously_ADV',
#  'psychologically_ADV',
#  'minimally_ADV',
#  'nicely_ADV',
#  'outside_ADV',
#  'onstage_ADV',
#  'elaborately_ADV',
#  'passionately_ADV',
#  'distinctively_ADV',
#  'anew_ADV',
#  'disproportionately_ADV',
#  'artistically_ADV',
#  'securely_ADV',
#  'terribly_ADV',
#  'insofar_ADV',
#  'knowingly_ADV',
#  'convincingly_ADV',
#  'hotly_ADV',
#  'unwittingly_ADV',
#  'miraculously_ADV',
#  'cheaply_ADV',
#  'strikingly_ADV',
#  'intensively_ADV',
#  'distantly_ADV',
#  'neatly_ADV',
#  'yes_ADV',
#  'conceptually_ADV',
#  'provisionally_ADV',
#  'casually_ADV',
#  'sparingly_ADV',
#  'single-handedly_ADV',
#  'suitably_ADV',
#  'generously_ADV',
#  'geologically_ADV',
#  'irregularly_ADV',
#  'tremendously_ADV',
#  'sequentially_ADV',
#  'finitely_ADV',
#  'outwardly_ADV',
#  'momentarily_ADV',
#  'hardest_ADV',
#  'correspondingly_ADV',
#  'fondly_ADV',
#  'upstairs_ADV',
#  'relentlessly_ADV',
#  'louder_ADV',
#  'boldly_ADV',
#  'rightly_ADV',
#  'vividly_ADV',
#  'loose_ADV',
#  'graphically_ADV',
#  'someday_ADV',
#  'high_ADV',
#  'fluently_ADV',
#  'gravely_ADV',
#  'conclusively_ADV',
#  'worse_ADV',
#  'due_ADV',
#  'aptly_ADV',
#  'competitively_ADV',
#  'solidly_ADV',
#  'seamlessly_ADV',
#  'abnormally_ADV',
#  'urgently_ADV',
#  'identically_ADV',
#  'frankly_ADV',
#  'retrospectively_ADV',
#  'terminally_ADV',
#  'near_ADV',
#  'modestly_ADV',
#  'wonderfully_ADV',
#  'creatively_ADV',
#  'ecologically_ADV',
#  'soundly_ADV',
#  'summarily_ADV',
#  'aloft_ADV',
#  'sincerely_ADV',
#  'grossly_ADV',
#  'natively_ADV',
#  'intrinsically_ADV',
#  'tragically_ADV',
#  'meticulously_ADV',
#  '7th_ADV',
#  'anytime_ADV',
#  'least_ADV',
#  'magically_ADV',
#  'softly_ADV',
#  'proportionally_ADV',
#  'customarily_ADV',
#  'bravely_ADV',
#  'morphologically_ADV',
#  'plain_ADV',
#  'thematically_ADV',
#  'plainly_ADV',
#  'powerfully_ADV',
#  'monthly_ADV',
#  'preferentially_ADV',
#  'linguistically_ADV',
#  'objectively_ADV',
#  'realistically_ADV',
#  'empirically_ADV',
#  'calmly_ADV',
#  'inwards_ADV',
#  'northeastward_ADV',
#  'quick_ADV',
#  'honorably_ADV',
#  'legitimately_ADV',
#  'covertly_ADV',
#  'painfully_ADV',
#  'thirdly_ADV',
#  'cleverly_ADV',
#  'op._ADV',
#  'intuitively_ADV',
#  'humorously_ADV',
#  'rigorously_ADV',
#  'surgically_ADV',
#  'ideologically_ADV',
#  'defensively_ADV',
#  'hopelessly_ADV',
#  'darkly_ADV',
#  'nationwide_ADV',
#  'purposefully_ADV',
#  'tirelessly_ADV',
#  'persistently_ADV',
#  'damned_ADV',
#  'comprehensively_ADV',
#  'deeper_ADV',
#  'inversely_ADV',
#  'vocally_ADV',
#  'insufficiently_ADV',
#  'materially_ADV',
#  'wisely_ADV',
#  'inexplicably_ADV',
#  'spatially_ADV',
#  'neither_ADV',
#  'staunchly_ADV',
#  'lavishly_ADV',
#  'handily_ADV',
#  'skillfully_ADV',
#  'amazingly_ADV',
#  'alight_ADV',
#  'endlessly_ADV',
#  'hurriedly_ADV',
#  'doubly_ADV',
#  'unnecessarily_ADV',
#  'cautiously_ADV',
#  'confidently_ADV',
#  'gladly_ADV',
#  'overnight_ADV',
#  'horribly_ADV',
#  'satisfactorily_ADV',
#  'faintly_ADV',
#  'computationally_ADV',
#  'north-northwest_ADV',
#  'conspicuously_ADV',
#  'collaboratively_ADV',
#  'passively_ADV',
#  'longitudinally_ADV',
#  'paradoxically_ADV',
#  'solemnly_ADV',
#  'unlawfully_ADV',
#  'northwestward_ADV',
#  'intricately_ADV',
#  'offensively_ADV',
#  'effortlessly_ADV',
#  'thickly_ADV',
#  'impressively_ADV',
#  'dearly_ADV',
#  'hereby_ADV',
#  'collegiately_ADV',
#  'chronically_ADV',
#  'thrice_ADV',
#  'brighter_ADV',
#  'perpetually_ADV',
#  'dorsally_ADV',
#  'resupply_ADV',
#  'lawfully_ADV',
#  'symmetrically_ADV',
#  'anteriorly_ADV',
#  'keenly_ADV',
#  'amicably_ADV',
#  'confusingly_ADV',
#  'frantically_ADV',
#  'unconditionally_ADV',
#  'optically_ADV',
#  'furiously_ADV',
#  'acutely_ADV',
#  'indiscriminately_ADV',
#  'phonetically_ADV',
#  'industrially_ADV',
#  'emphatically_ADV',
#  'piecemeal_ADV',
#  'diligently_ADV',
#  'abundantly_ADV',
#  'politely_ADV',
#  'eternally_ADV',
#  'energetically_ADV',
#  'rigidly_ADV',
#  'posteriorly_ADV',
#  'unjustly_ADV',
#  'generically_ADV',
#  'wrongfully_ADV',
#  'discreetly_ADV',
#  'habitually_ADV',
#  'unequivocally_ADV',
#  'elegantly_ADV',
#  'hereafter_ADV',
#  'autonomously_ADV',
#  'criminally_ADV',
#  'metaphorically_ADV',
#  'categorically_ADV',
#  'respectfully_ADV',
#  'kind_ADV',
#  'madly_ADV',
#  'inappropriately_ADV',
#  'justly_ADV',
#  'unduly_ADV',
#  'sarcastically_ADV',
#  'crucially_ADV',
#  'awry_ADV',
#  'unquestionably_ADV',
#  'duller_ADV',
#  'squarely_ADV',
#  'smarter_ADV',
#  'geometrically_ADV',
#  'pleasantly_ADV',
#  'fourth_ADV',
#  'recursively_ADV',
#  'oftentimes_ADV',
#  'thermally_ADV',
#  'admittedly_ADV',
#  'unambiguously_ADV',
#  'cooperatively_ADV',
#  'bluntly_ADV',
#  'organically_ADV',
#  'astray_ADV',
#  'profusely_ADV',
#  'admirably_ADV',
#  'cleanly_ADV',
#  'instantaneously_ADV',
#  'undeniably_ADV',
#  'predictably_ADV',
#  'blatantly_ADV',
#  'comically_ADV',
#  'liberally_ADV',
#  'superbly_ADV',
#  'awkwardly_ADV',
#  'ruthlessly_ADV',
#  'ventrally_ADV',
#  'thereupon_ADV',
#  'belatedly_ADV',
#  'spectacularly_ADV',
#  'tactically_ADV',
#  'transversely_ADV',
#  'etymologically_ADV',
#  'flatly_ADV',
#  'downriver_ADV',
#  'ah_ADV',
#  'fraudulently_ADV',
#  'involuntarily_ADV',
#  'unsurprisingly_ADV',
#  'tearfully_ADV',
#  'unconsciously_ADV',
#  'ritually_ADV',
#  'anatomically_ADV',
#  'quarterly_ADV',
#  'viciously_ADV',
#  'radially_ADV',
#  'palaeographically_ADV',
#  'surreptitiously_ADV',
#  'patiently_ADV',
#  'grammatically_ADV',
#  'mercilessly_ADV',
#  'divinely_ADV',
#  'rhythmically_ADV',
#  'philosophically_ADV',
#  'semantically_ADV',
#  'rationally_ADV',
#  'understandably_ADV',
#  'singularly_ADV',
#  'provincially_ADV',
#  'lovingly_ADV',
#  'triple_ADV',
#  'instinctively_ADV',
#  'cruelly_ADV',
#  'downstairs_ADV',
#  '15th_ADV',
#  'sure_ADV',
#  'hydraulically_ADV',
#  'acoustically_ADV',
#  'graciously_ADV',
#  'clandestinely_ADV',
#  'overtime_ADV',
#  'blindly_ADV',
#  'henceforth_ADV',
#  'memorably_ADV',
#  'theologically_ADV',
#  'ethically_ADV',
#  'gracefully_ADV',
#  'asymptotically_ADV',
#  'delicately_ADV',
#  'playfully_ADV',
#  'inextricably_ADV',
#  'quantitatively_ADV',
#  'ceremonially_ADV',
#  'bit_ADV',
#  'north-west_ADV',
#  'prolifically_ADV',
#  'evolutionarily_ADV',
#  'expertly_ADV',
#  'proportionately_ADV',
#  'inaccurately_ADV',
#  'optimally_ADV',
#  'exquisitely_ADV',
#  'stubbornly_ADV',
#  'inwardly_ADV',
#  'algebraically_ADV',
#  'rightfully_ADV',
#  'telepathically_ADV',
#  'figuratively_ADV',
#  'eminently_ADV',
#  'incrementally_ADV',
#  'speedily_ADV',
#  'recklessly_ADV',
#  'herein_ADV',
#  'deceptively_ADV',
#  'contractually_ADV',
#  'miserably_ADV',
#  'coldly_ADV',
#  'thereto_ADV',
#  'ably_ADV',
#  'savagely_ADV',
#  'resolutely_ADV',
#  'inadequately_ADV',
#  'secondarily_ADV',
#  'face-to-face_ADV',
#  'canonically_ADV',
#  'qualitatively_ADV',
#  'unfavorably_ADV',
#  'developmentally_ADV',
#  'adamantly_ADV',
#  'painstakingly_ADV',
#  'willfully_ADV',
#  'validly_ADV',
#  'crudely_ADV',
#  'covalently_ADV',
#  'conditionally_ADV',
#  'thankfully_ADV',
#  'steadfastly_ADV',
#  'deftly_ADV',
#  'heretofore_ADV',
#  'triumphantly_ADV',
#  'strenuously_ADV',
#  'profitably_ADV',
#  'responsibly_ADV',
#  'downright_ADV',
#  'west-northwest_ADV',
#  'peculiarly_ADV',
#  'sonically_ADV',
#  'earnestly_ADV',
#  'spirally_ADV',
#  'municipally_ADV',
#  'variably_ADV',
#  'topologically_ADV',
#  'full-time_ADV',
#  'wholeheartedly_ADV',
#  'suspiciously_ADV',
#  'temporally_ADV',
#  'roundly_ADV',
#  'prohibitively_ADV',
#  ...]

# %%
#wiki_w2v.word_vec('Dominican::Republic_PROPN') 
#wiki_w2v.similarity(w1,w2)
'Film_PROPN' in voc
wiki_w2v.similar_by_word('Film_PROPN')
# Out:
# [('Documentary_PROPN', 0.7497795820236206),
#  ('Festival_PROPN', 0.7208018898963928),
#  ('FIPRESCI_PROPN', 0.7063645124435425),
#  ('Audience_PROPN', 0.6939208507537842),
#  ('Outfest_PROPN', 0.6913202404975891),
#  ('Cinequest_PROPN', 0.6887915730476379),
#  ('Seattle::International::Film::Festival_PROPN', 0.6837893724441528),
#  ('Fantasporto_PROPN', 0.6767797470092773),
#  ('Cinema_PROPN', 0.6761119365692139),
#  ('Sundance_PROPN', 0.6749467849731445)]

# %% [markdown]
# Since words in the gensim model are in the form 'word_LEMM', and in FB15 they are in 'm/id' form, to compute similarity we need to convert m/id to 'word_LEMM'.
# The file `mid2name.tsv` provides mapping from 'm/id' to 'word'. Apparently most words in FB15 are proper nouns, so we are going to convert  each m/id to 'word_PROPN'.
#
# To this end, we simply add '\_PROPN' to every word in `mid2name.tsv`. Blank spaces should also be replaced with '::'. The function `convert_to_wiki_form` makes these changes for each given input word.
#
# Note that there are many duplicates in `mid2name.tsv`. The data is loaded into a data frame and the duplicates are dropped, keeping only the first instance for each mid. Then a dictionary is created mapping mids to word_LEMMs.
#
# Using this dictionary we can later map every entity `ent_i` to a lemmatized word `ent_LEMM_i` and then compare it with another by `wiki_w2v.similarity(ent_lemm_i,ent_lemm_j)`. We also need a threshold to compare this quantity with.

# %%
df = pd.read_csv('./FB15K/mid2name.tsv', sep='\t', header=None, names=['mid','word'])

# %%
df.loc[df['mid'] == '/m/027rn']  # It has many duplicates
# Out:
#            mid                word
# 3403  /m/027rn  Dominican Republic

# %%
# dropping ALL duplicte values 
df.drop_duplicates(subset ="mid", 
                     keep = 'first', inplace = True) 


df.loc[df['mid'] == '/m/027rn']
# Out:
#            mid                word
# 3403  /m/027rn  Dominican Republic

# %%
def convert_to_wiki_form(ent: str):
    ent = ent.replace(' ', '::')
    ent = ent + '_PROPN'
    return ent

# %%
#file.head()
keys = list(df['mid'])
mapping = list(df['word'])
mapp_lemm = [convert_to_wiki_form(str(w)) for w in mapping] # words lemmatized

# %%
mapping_dict = dict(zip(keys,mapp_lemm))

# %%
mapping_dict['/m/027rn']
# Out:
# 'Dominican::Republic_PROPN'

# %% [markdown]
# --------

# %% [markdown]
# ## Read entity2id.txt and create the similarity matrix/data frame.

# %% [markdown]
# First we read "/OpenKE/benchmarks/FB15K/entity2id.txt" into a data frame.

# %%
ents = pd.read_csv("./OpenKE/benchmarks/FB15K/entity2id.txt",
                   sep = '\t',header=None, names=['mid'], skiprows=[0],usecols=[0]) # first row is lineTot

# %%
mid = ents.iloc[3]['mid']

# %%
ent_lemm = mapping_dict[mid]

# %%
ent_lemm in voc
# Out:
# False

# %% [markdown]
# Apparently some words are not found in w2v vocabulary. So we look into it:

# %%
in_w2v =0
not_in_dict = 0
subset = []      # The subset of words from FB15 that are in w2v.
not_in_w2v = []  # And the ones that aren't.
for i in range(len(ents)):
    mid = ents.iloc[i]['mid']
    try:
        ent_lemm = mapping_dict[mid] 
        if ent_lemm in voc:
            in_w2v +=1
            subset.append( (i,mid,ent_lemm) )
        else:
            not_in_w2v.append((i,mid,ent_lemm))
            
    except KeyError: # These words are not even in mid2name.tsv. The mids don't exist.
        not_in_dict += 1

# %%
not_in_dict   # This many are no found in mid2name.tsv
# Out:
# 185

# %% [markdown]
# Not that many, so it's cool.

# %%
in_w2v        # This many were found in word2vec vocabulary
# Out:
# 7088

# %% [markdown]
# That's less than half of FB15K. Not cool, but let's move on:

# %%
subset[:3] # We have collected them all in a list. (id, mid, word_lemm). id -> entity2id.txt
# Out:
# [(0, '/m/027rn', 'Dominican::Republic_PROPN'),
#  (1, '/m/06cx9', 'Republic_PROPN'),
#  (6, '/m/01sl1q', 'Michelle::Rodriguez_PROPN')]

# %%
not_in_w2v # a peak into the words that are not in w2v. at least not in this format.
# Out:
# [(2, '/m/017dcd', 'Mighty::Morphin::Power::Rangers_PROPN'),
#  (3, '/m/06v8s0', 'Wendee::Lee_PROPN'),
#  (4, '/m/07s9rl0', 'Drama::film_PROPN'),
#  (5, '/m/0170z3', 'American::History::X_PROPN'),
#  (8, '/m/0cnk2q', 'Australia::national::association::football::team_PROPN'),
#  (10, '/m/02_j1w', 'Defender::(association::football)_PROPN'),
#  (13, '/m/03h_f4', '34th::Canadian::Parliament_PROPN'),
#  (14, '/m/011yn5', 'As::Good::as::It::Gets_PROPN'),
#  (16, '/m/04nrcg', 'Maldives::national::football::team_PROPN'),
#  (17, '/m/02sdk9v', 'Forward::(association::football)_PROPN'),
#  (19, '/m/014lc_', 'Star::Trek::Nemesis_PROPN'),
#  (20, '/m/05cvgl', 'The::Remains::of::the::Day::(film)_PROPN'),
#  (21,
#   '/m/04kxsb',
#   'BAFTA::Award::for::Best::Actor::in::a::Leading::Role_PROPN'),
#  (22, '/m/02qyp19', 'BAFTA::Award::for::Best::Original::Screenplay_PROPN'),
#  (23, '/m/02d413', 'Philadelphia::(film)_PROPN'),
#  (28, '/m/09w1n', 'Alpine::skiing_PROPN'),
#  (29, '/m/0sx8l', '1980::Winter::Olympics_PROPN'),
#  (32, '/m/0gqng', 'Academy::Award::for::Best::Foreign::Language::Film_PROPN'),
#  (33, '/m/073hkh', '61st::Academy::Awards_PROPN'),
#  (34, '/m/0b76d_m', 'Anonymous::(film)_PROPN'),
#  (35, '/m/029j_', 'DVD_PROPN'),
#  (38, '/m/014_x2', 'City::of::Angels::(film)_PROPN'),
#  (39, '/m/012ljv', 'Gabriel::Yared_PROPN'),
#  (40, '/m/0ds35l9', 'Bridesmaids::(2011::film)_PROPN'),
#  (43, '/m/02bjrlw', 'Italian::language_PROPN'),
#  (45, '/m/02s2ft', 'Chris::Cooper::(actor)_PROPN'),
#  (47, '/m/03ckfl9', 'Experimental::music_PROPN'),
#  (51, '/m/063k3h', 'Scotch-Irish::American_PROPN'),
#  (53, '/m/019v9k', "Bachelor's::degree_PROPN"),
#  (54, '/m/02681vq', 'Latin::Grammy::Award::for::Record::of::the::Year_PROPN'),
#  (56, '/m/0gx_st', '58th::Primetime::Emmy::Awards_PROPN'),
#  (57,
#   '/m/09qvf4',
#   'Primetime::Emmy::Award::for::Outstanding::Guest::Actress::in::a::Comedy::Series_PROPN'),
#  (59, '/m/0rs6x', 'St.::Augustine,::Florida_PROPN'),
#  (61, '/m/0d90m', 'X-Men::(film)_PROPN'),
#  (65,
#   '/m/04ljl_l',
#   'Golden::Raspberry::Award::for::Worst::Supporting::Actor_PROPN'),
#  (66, '/m/03qcfvw', 'G.I.::Joe:::The::Rise::of::Cobra_PROPN'),
#  (68, '/m/05sxg2', 'Theatrical::producer_PROPN'),
#  (69, '/m/02ynfr', 'Art::director_PROPN'),
#  (70, '/m/0bmch_x', 'Unknown::(2011::film)_PROPN'),
#  (74, '/m/01jr4j', 'Topaz::(1969::film)_PROPN'),
#  (75, '/m/0rh6k', 'Washington,::D.C._PROPN'),
#  (77, '/m/03mqtr', 'Political::drama_PROPN'),
#  (78, '/m/04j4tx', 'The::Killing::Fields::(film)_PROPN'),
#  (80, '/m/07zhjj', 'How::I::Met::Your::Mother_PROPN'),
#  (82,
#   '/m/027dtxw',
#   'BAFTA::Award::for::Best::Actor::in::a::Supporting::Role_PROPN'),
#  (83, '/m/05hs4r', 'Heartland::rock_PROPN'),
#  (87, '/m/01lxd4', 'Avant-garde::jazz_PROPN'),
#  (91, '/m/08nhfc1', 'Crazy::Heart_PROPN'),
#  (93, '/m/0g56t9t', 'Frankenweenie::(2012::film)_PROPN'),
#  (94, '/m/062zm5h', 'The::Avengers::(2012::film)_PROPN'),
#  (97, '/m/0dbpyd', 'Alan::Burnett_PROPN'),
#  (98, '/m/053y0s', 'Bill::Payne_PROPN'),
#  (99, '/m/0dz3r', 'Record::producer_PROPN'),
#  (102, '/m/0b005', 'The::Muppet::Show_PROPN'),
#  (105, '/m/02wvfxl', 'Boston::College::Eagles::football_PROPN'),
#  (106, '/m/09sh8k', 'Fantastic::Four:::Rise::of::the::Silver::Surfer_PROPN'),
#  (107, '/m/09zzb8', 'Make-up::artist_PROPN'),
#  (108, '/m/05pd94v', '52nd::Grammy::Awards_PROPN'),
#  (109, '/m/01vvydl', 'Dr.::Dre_PROPN'),
#  (113, '/m/0m313', 'Shakespeare::in::Love_PROPN'),
#  (114, '/m/02y_lrp', 'The::Love::Guru_PROPN'),
#  (116, '/m/034qmv', 'Around::the::World::in::80::Days::(2004::film)_PROPN'),
#  (119, '/m/0g22z', 'Wall::Street::(1987::film)_PROPN'),
#  (120,
#   '/m/05b4l5x',
#   'Golden::Raspberry::Award::for::Worst::Supporting::Actress_PROPN'),
#  (121, '/m/018js4', 'Top::Gun_PROPN'),
#  (124, '/m/081jbk', 'Hilary::Haag_PROPN'),
#  (127,
#   '/m/02581q',
#   'Grammy::Award::for::Best::Classical::Crossover::Album_PROPN'),
#  (128, '/m/0sxg4', 'The::Dresser_PROPN'),
#  (129, '/m/04xvlr', 'Period::piece_PROPN'),
#  (130, '/m/02gpkt', 'Rush::Hour::(film)_PROPN'),
#  (133, '/m/07jnt', 'The::Shawshank::Redemption_PROPN'),
#  (134, '/m/0gq9h', 'Academy::Award::for::Best::Picture_PROPN'),
#  (136, '/m/083shs', 'The::Cider::House::Rules::(film)_PROPN'),
#  (137, '/m/0njvn', 'Berrien::County,::Michigan_PROPN'),
#  (138, '/m/09nqf', 'United::States::dollar_PROPN'),
#  (141, '/m/01br2w', 'The::Passion::of::the::Christ_PROPN'),
#  (142, '/m/0kq0q', 'Calaveras::County,::California_PROPN'),
#  (143, '/m/03rl1g', '32nd::United::States::Congress_PROPN'),
#  (145, '/m/0fbq2n', 'Oregon::Ducks::football_PROPN'),
#  (146, '/m/01r3hr', 'Running::back_PROPN'),
#  (147, '/m/060bp', 'Prime::minister_PROPN'),
#  (151, '/m/04yywz', 'Burt::Young_PROPN'),
#  (152, '/m/0140g4', 'Rocky::V_PROPN'),
#  (154, '/m/0k049', 'Beverly::Hills,::California_PROPN'),
#  (156, '/m/0337vz', 'Larenz::Tate_PROPN'),
#  (158, '/m/0b2v79', 'The::Untouchables::(film)_PROPN'),
#  (159, '/m/01c0cc', 'Berlin::Institute::of::Technology_PROPN'),
#  (160, '/m/01jc6q', 'Cabaret::(film)_PROPN'),
#  (161, '/m/040njc', 'BAFTA::Award::for::Best::Film_PROPN'),
#  (164, '/m/0520r2x', 'Richard::Day::(art::director)_PROPN'),
#  (165, '/m/0cb77r', 'Thomas::Little_PROPN'),
#  (168, '/m/0ds6bmk', 'Tyrannosaur::(film)_PROPN'),
#  (169,
#   '/m/05b3ts',
#   'Safety::(American::and::Canadian::football::position)_PROPN'),
#  (170, '/m/0g2hw4', 'Oregon::State::Beavers::football_PROPN'),
#  (171, '/m/0ktpx', 'Spellbound::(1945::film)_PROPN'),
#  (174, '/m/0dgrmp', 'Goalkeeper::(association::football)_PROPN'),
#  (175, '/m/028_yv', 'Once::Upon::a::Time::in::America_PROPN'),
#  (178, '/m/0bpbhm', "Cookie's::Fortune_PROPN"),
#  (179, '/m/0219x_', 'Independent::film_PROPN'),
#  (180, '/m/05_6_y', 'David::Healy::(footballer)_PROPN'),
#  (181, '/m/02b15h', 'Doncaster::Rovers::F.C._PROPN'),
#  (182, '/m/0487c3', 'Jason::Roberts::(footballer)_PROPN'),
#  (183, '/m/01j_jh', 'Bristol::Rovers::F.C._PROPN'),
#  (184, '/m/03c7ln', 'Jay::Bennett_PROPN'),
#  (186, '/m/01qvcr', 'Rare::Ltd._PROPN'),
#  (188, '/m/02pprs', 'Alto::saxophone_PROPN'),
#  (191, '/m/0784z', 'Six-Day::War_PROPN'),
#  (192, '/m/0kwgs', 'Madison::County,::Alabama_PROPN'),
#  (198, '/m/02_fm2', 'Treasure::Planet_PROPN'),
#  (199,
#   '/m/02x73k6',
#   'National::Society::of::Film::Critics::Award::for::Best::Supporting::Actor_PROPN'),
#  (200, '/m/02lxrv', 'Ed::Wood::(film)_PROPN'),
#  (202, '/m/016z4k', 'Singer-songwriter_PROPN'),
#  (203, '/m/06151l', 'Freddy::Rodriguez_PROPN'),
#  (204, '/m/06gp3f', 'Justina::Machado_PROPN'),
#  (205, '/m/01fq7', 'Battle::Creek,::Michigan_PROPN'),
#  (206, '/m/06w99h3', 'Rango::(2011::film)_PROPN'),
#  (207, '/m/02kdv5l', 'Action::film_PROPN'),
#  (209, '/m/08r4x3', 'Bobby::(2006::film)_PROPN'),
#  (219, '/m/02rc4d', 'Son::Goku::(Dragon::Ball)_PROPN'),
#  (221, '/m/027qgy', 'My::Big::Fat::Greek::Wedding_PROPN'),
#  (222, '/m/06cvj', 'Romantic::comedy::film_PROPN'),
#  (223, '/m/01mkq', 'Computer::science_PROPN'),
#  (224, '/m/011xy1', 'Trinity::College,::Dublin_PROPN'),
#  (225, '/m/0dxtw', 'Special::effect_PROPN'),
#  (226, '/m/0cq86w', 'Oliver!::(film)_PROPN'),
#  (229, '/m/06_kh', 'Santa::Monica,::California_PROPN'),
#  (230, '/m/02hrh1q', 'Actor_PROPN'),
#  (233, '/m/01mw1', 'Video::game_PROPN'),
#  (234, '/m/02wh75', 'Grammy::Award::for::Best::Rock::Song_PROPN'),
#  (235, '/m/0lbj1', 'Sting::(musician)_PROPN'),
#  (236, '/m/0c3ybss', 'Insidious::(film)_PROPN'),
#  (239, '/m/06wxw', 'St.::Louis,::Missouri_PROPN'),
#  (241, '/m/0np9r', 'Voice::acting_PROPN'),
#  (242, '/m/05bp8g', 'Kaneto::Shiozawa_PROPN'),
#  (244, '/m/0p07l', 'El::Paso::County,::Colorado_PROPN'),
#  (245, '/m/01vsl', 'Colorado::Springs,::Colorado_PROPN'),
#  (246, '/m/02vp1f_', 'Quest::for::Fire::(film)_PROPN'),
#  (248, '/m/060__y', 'Film::adaptation_PROPN'),
#  (249, '/m/03rtz1', 'North::(film)_PROPN'),
#  (250, '/m/09m6kg', 'A::Beautiful::Mind::(film)_PROPN'),
#  (251, '/m/02h40lc', 'English::language_PROPN'),
#  (252, '/m/047q2k1', '3::Idiots_PROPN'),
#  (253, '/m/05p553', 'Anarchic::comedy::film_PROPN'),
#  (255, '/m/02dwn9', 'Starting::pitcher_PROPN'),
#  (261, '/m/02rchht', 'Jon::Avnet_PROPN'),
#  (262, '/m/0dq3c', 'Vice::president_PROPN'),
#  (266, '/m/06wzvr', "Can't::Stop::the::Music_PROPN"),
#  (267, '/m/01q03', 'Cult::film_PROPN'),
#  (268, '/m/01qn7n', 'The::O.C._PROPN'),
#  (270, '/m/03tps5', 'Meet::the::Fockers_PROPN'),
#  (271, '/m/0cnl80', 'Phyllis::Smith_PROPN'),
#  (273, '/m/0gq_v', 'Academy::Award::for::Best::Art::Direction_PROPN'),
#  (274, '/m/0k2cb', 'Dangerous::Liaisons_PROPN'),
#  (277, '/m/0c0yh4', 'Sunshine::(1999::film)_PROPN'),
#  (282, '/m/03g90h', 'Babylon::5:::The::Gathering_PROPN'),
#  (283, '/m/02_n3z', 'Dialogue::editor_PROPN'),
#  (285, '/m/0827d', 'World::music_PROPN'),
#  (288, '/m/05m63c', 'Krista::Allen_PROPN'),
#  (289, '/m/0yyg4', 'Mississippi::Burning_PROPN'),
#  (290,
#   '/m/027c924',
#   'National::Board::of::Review::Award::for::Best::Director_PROPN'),
#  (297, '/m/090s_0', "Gulliver's::Travels::(TV::miniseries)_PROPN"),
#  (299, '/m/05znxx', 'The::Fugitive::(1993::film)_PROPN'),
#  (300,
#   '/m/02hsq3m',
#   'BAFTA::Award::for::Best::Special::Visual::Effects_PROPN'),
#  (301, '/m/01kyvx', 'Voice::acting::in::Japan_PROPN'),
#  (302, '/m/0ckr7s', 'Sailor::Moon::R:::The::Movie_PROPN'),
#  (305, '/m/05ztjjw', 'MTV::Movie::Award::for::Best::Movie_PROPN'),
#  (308, '/m/04h68j', 'James::Wong::(producer)_PROPN'),
#  (309, '/m/01g3gq', 'Final::Destination_PROPN'),
#  (311, '/m/01gbcf', 'Math::rock_PROPN'),
#  (312, '/m/016clz', 'Alternative::rock_PROPN'),
#  (313, '/m/011yrp', 'Life::Is::Beautiful_PROPN'),
#  (316, '/m/05jf85', 'The::Purple::Rose::of::Cairo_PROPN'),
#  (317, '/m/046f25', 'Grenada::national::football::team_PROPN'),
#  (318, '/m/0d1swh', 'Craig::Rocastle_PROPN'),
#  (320, '/m/04t36', 'Musical::film_PROPN'),
#  (321, '/m/011yxg', 'Moulin::Rouge!_PROPN'),
#  (322, '/m/05v38p', 'Chocolat::(2000::film)_PROPN'),
#  (323,
#   '/m/03hkv_r',
#   'Writers::Guild::of::America::Award::for::Best::Adapted::Screenplay_PROPN'),
#  (324, '/m/025twgf', 'Dr.::No::(film)_PROPN'),
#  (325, '/m/0clpml', 'James::Bond::(character)_PROPN'),
#  (326, '/m/0t015', 'Iowa::City,::Iowa_PROPN'),
#  (332, '/m/07xl34', 'Chancellor::(education)_PROPN'),
#  (333, '/m/02sgy', 'Electric::guitar_PROPN'),
#  (334, '/m/0l14md', 'Percussion::instrument_PROPN'),
#  (338, '/m/01d_h8', 'Film::producer_PROPN'),
#  (339, '/m/0c_j9x', 'Murder::on::the::Orient::Express::(1974::film)_PROPN'),
#  (340, '/m/0n5j_', 'Bergen::County,::New::Jersey_PROPN'),
#  (341, '/m/0fm9_', 'Rockland::County,::New::York_PROPN'),
#  (342, '/m/04cy8rb', 'Conrad::Buff::IV_PROPN'),
#  (343, '/m/07gp9', 'Terminator::2:::Judgment::Day_PROPN'),
#  (344, '/m/081pw', 'World::War::II_PROPN'),
#  (345, '/m/0gzy02', 'The::Guns::of::Navarone::(film)_PROPN'),
#  (349, '/m/03t5kl', 'Grammy::Award::for::Best::Rap/Sung::Collaboration_PROPN'),
#  (350, '/m/01f2q5', 'The::Roots_PROPN'),
#  (352, '/m/01l849', 'Gold::(color)_PROPN'),
#  (353, '/m/0f4y_', 'Delaware::County,::New::York_PROPN'),
#  (355, '/m/0789n', 'Secretary::of::State_PROPN'),
#  (357, '/m/0mdxd', 'Music::video_PROPN'),
#  (358, '/m/03x3qv', 'Joshua::Malina_PROPN'),
#  (359, '/m/0g60z', 'The::West::Wing_PROPN'),
#  (361, '/m/01hr1', 'Batman::Forever_PROPN'),
#  (363,
#   '/m/026mg3',
#   'Grammy::Award::for::Best::Country::Instrumental::Performance_PROPN'),
#  (364, '/m/01s695', '42nd::Grammy::Awards_PROPN'),
#  (367, '/m/0hx4y', 'Jurassic::Park::(film)_PROPN'),
#  (369, '/m/0k611', 'Academy::Award::for::Best::Film::Editing_PROPN'),
#  (373, '/m/04njml', 'Tony::Award::for::Best::Original::Score_PROPN'),
#  (374, '/m/07hgkd', 'David::Shire_PROPN'),
#  (378, '/m/0b1f49', 'Brad::Grey_PROPN'),
#  (379, '/m/01gxqf', 'Macclesfield::Town::F.C._PROPN'),
#  (380, '/m/01_qc_', 'Pancreatic::cancer_PROPN'),
#  (382, '/m/0c55fj', 'BBC::HD_PROPN'),
#  (383, '/m/09xbpt', "Ocean's::Thirteen_PROPN"),
#  (385, '/m/02w7gg', 'English::people_PROPN'),
#  (386, '/m/05f4m9q', 'Golden::Raspberry::Award::for::Worst::Director_PROPN'),
#  (387, '/m/08lr6s', 'The::Scarlet::Letter::(1995::film)_PROPN'),
#  (392, '/m/0495ys', '93rd::United::States::Congress_PROPN'),
#  (393, '/m/05l2z4', '90th::United::States::Congress_PROPN'),
#  (394, '/m/018wrk', '1904::Summer::Olympics_PROPN'),
#  (398,
#   '/m/047gn4y',
#   'Prince::of::Persia:::The::Sands::of::Time::(film)_PROPN'),
#  (400, '/m/0bvn25', 'Knocked::Up_PROPN'),
#  (401, '/m/026p4q7', 'The::Curious::Case::of::Benjamin::Button::(film)_PROPN'),
#  (406, '/m/01g888', 'Ska::punk_PROPN'),
#  (409, '/m/0m27n', 'Maricopa::County,::Arizona_PROPN'),
#  (410, '/m/0qpjt', 'Chandler,::Arizona_PROPN'),
#  (414, '/m/017fp', 'Biography_PROPN'),
#  (415, '/m/01gsvb', '18th::United::States::Congress_PROPN'),
#  (418, '/m/01r42_g', 'Jamie-Lynn::Sigler_PROPN'),
#  (419,
#   '/m/0gr51',
#   'Academy::Award::for::Best::Writing::(Original::Screenplay)_PROPN'),
#  (421, '/m/0ddfwj1', 'Submarine::(2010::film)_PROPN'),
#  (422, '/m/0sv6n', 'Burlington,::Iowa_PROPN'),
#  (423, '/m/02wkmx', "Palme::d'Or_PROPN"),
#  (426, '/m/0126y2', 'Ja::Rule_PROPN'),
#  (427, '/m/01flzq', 'Hardcore::hip::hop_PROPN'),
#  (429,
#   '/m/0bfvw2',
#   'Primetime::Emmy::Award::for::Outstanding::Supporting::Actress::in::a::Miniseries::or::a::Movie_PROPN'),
#  (431, '/m/0dq626', 'Holes::(film)_PROPN'),
#  (432, '/m/07sbbz2', 'Rock::and::roll_PROPN'),
#  (435, '/m/02zq43', 'Thomas::Sangster_PROPN'),
#  (437, '/m/0czyxs', 'Watchmen::(film)_PROPN'),
#  (440, '/m/0ds3t5x', 'The::Help::(film)_PROPN'),
#  (444, '/m/0l6vl', '1980::Summer::Olympics_PROPN'),
#  (445, '/m/02tcgh', 'Kal::Ho::Naa::Ho_PROPN'),
#  (446, '/m/0kvgnq', 'The::Unbearable::Lightness::of::Being::(film)_PROPN'),
#  (447, '/m/02x4wr9', 'Independent::Spirit::Award::for::Best::Director_PROPN'),
#  (448, '/m/017z49', 'Memento::(film)_PROPN'),
#  (449, '/m/08p1gp', 'Luci::Christian_PROPN'),
#  (450, '/m/0dnvn3', 'The::Ladykillers::(2004::film)_PROPN'),
#  (451, '/m/07zrf', 'Vietnamese::language_PROPN'),
#  (452, '/m/016fyc', 'The::Usual::Suspects_PROPN'),
#  (458, '/m/02pw_n', 'Garden::State::(film)_PROPN'),
#  (461, '/m/0fr63l', 'Mighty::Joe::Young::(1998::film)_PROPN'),
#  (463, '/m/05zr6wv', 'MTV::Movie::Award::for::Best::On-Screen::Duo_PROPN'),
#  (464, '/m/0cjk9', 'Ukrainian::language_PROPN'),
#  (466, '/m/0s3y5', 'Urbana,::Illinois_PROPN'),
#  (468, '/m/07xtqq', "One::Flew::Over::the::Cuckoo's::Nest::(film)_PROPN"),
#  (469, '/m/05hcy', 'Nassau,::Bahamas_PROPN'),
#  (474, '/m/03w5xm', 'Customer::service_PROPN'),
#  (475, '/m/026v437', 'Paz::de::la::Huerta_PROPN'),
#  (476, '/m/080dwhx', 'Boardwalk::Empire_PROPN'),
#  (478, '/m/05bt6j', 'Pop::rock_PROPN'),
#  (479, '/m/01k1k4', 'Austin::Powers:::The::Spy::Who::Shagged::Me_PROPN'),
#  (480, '/m/09gq0x5', "The::King's::Speech_PROPN"),
#  (483, '/m/02rbdlq', 'Scottish::Canadian_PROPN'),
#  (485, '/m/095zlp', 'The::Hours::(film)_PROPN'),
#  (491, '/m/0hhbr', 'Art::museum_PROPN'),
#  (492, '/m/03ckxdg', 'Elizabeth::Page_PROPN'),
#  (493, '/m/02_1q9', 'Another::World::(TV::series)_PROPN'),
#  (494, '/m/09n48', '2002::Winter::Olympics_PROPN'),
#  (495, '/m/020qr4', 'Sonic::X_PROPN'),
#  (497, '/m/02lq67', 'Bronze::medal_PROPN'),
#  (498, '/m/0fvwg', 'Annapolis,::Maryland_PROPN'),
#  (499, '/m/0dtw1x', 'The::Aristocrats::(film)_PROPN'),
#  (502, '/m/03rs8y', 'Eriq::La::Salle_PROPN'),
#  (505, '/m/0m2kd', 'Stand::by::Me::(film)_PROPN'),
#  (506, '/m/0jdk_', '2000::Summer::Olympics_PROPN'),
#  (507, '/m/064vjs', 'Canoe::racing_PROPN'),
#  (508, '/m/042v_gx', 'Acoustic::guitar_PROPN'),
#  (510,
#   '/m/03qbh5',
#   'Grammy::Award::for::Best::Pop::Collaboration::with::Vocals_PROPN'),
#  (512, '/m/052q4j', 'Catholic::school_PROPN'),
#  (515, '/m/0bzjvm', '48th::Academy::Awards_PROPN'),
#  (516, '/m/0cj_v7', 'Derby::County::F.C._PROPN'),
#  (520,
#   '/m/0bp_b2',
#   'Primetime::Emmy::Award::for::Outstanding::Guest::Actor::in::a::Drama::Series_PROPN'),
#  (521, '/m/02fqrf', 'Batman::Begins_PROPN'),
#  (522, '/m/057xs89', 'MTV::Movie::Award::for::Best::Villain_PROPN'),
#  (523, '/m/05y7hc', 'Craig::Armstrong::(composer)_PROPN'),
#  (526, '/m/034qrh', 'DodgeBall:::A::True::Underdog::Story_PROPN'),
#  (527, '/m/050023', 'Richard::Culliton_PROPN'),
#  (528, '/m/026dcvf', 'Christopher::Whitesell_PROPN'),
#  (529, '/m/0195fx', 'Rapid::transit_PROPN'),
#  (530, '/m/0m_sb', 'Northern::line_PROPN'),
#  (532, '/m/01t_xp_', 'Rush::(band)_PROPN'),
#  (533, '/m/021gt5', 'Litchfield,::Connecticut_PROPN'),
#  (536, '/m/0436f4', 'Vincent::Pastore_PROPN'),
#  (540, '/m/0plyy', 'Terre::Haute,::Indiana_PROPN'),
#  (542,
#   '/m/099jhq',
#   'Broadcast::Film::Critics::Association::Award::for::Best::Supporting::Actor_PROPN'),
#  (543, '/m/0sx7r', '1992::Winter::Olympics_PROPN'),
#  (544, '/m/03tmr', 'Ice::hockey_PROPN'),
#  (548,
#   '/m/0789_m',
#   'Tony::Award::for::Best::Leading::Actor::in::a::Play_PROPN'),
#  (549, '/m/054_mz', 'Lawrence::Bender_PROPN'),
#  (553, '/m/0jsf6', 'The::Godfather::Part::II_PROPN'),
#  (556,
#   '/m/05zkcn5',
#   'MTV::Movie::Award::for::Best::Song::from::a::Movie_PROPN'),
#  (557, '/m/03mh94', 'Robots::(film)_PROPN'),
#  (559, '/m/05k17c', 'Dean::(education)_PROPN'),
#  (560, '/m/05vsb7', '2005::NFL::Draft_PROPN'),
#  (562, '/m/01vx2h', 'Visual::effects_PROPN'),
#  (563, '/m/06x43v', 'Rush::Hour::3_PROPN'),
#  (565, '/m/02snj9', 'Programming::(music)_PROPN'),
#  (566, '/m/0dckvs', 'Election::2_PROPN'),
#  (567, '/m/02r96rf', 'Visual::effects::supervisor_PROPN'),
#  (570,
#   '/m/0clfdj',
#   'Broadcast::Film::Critics::Association::Awards::2001_PROPN'),
#  (571, '/m/09fqtq', 'James::Wilby_PROPN'),
#  (573, '/m/01pfr3', 'Garbage::(band)_PROPN'),
#  (576, '/m/027z0pl', 'Gary::Barber_PROPN'),
#  (577, '/m/0drnwh', 'Memoirs::of::a::Geisha::(film)_PROPN'),
#  (578, '/m/058kh7', "She's::Having::a::Baby_PROPN"),
#  (581, '/m/0bynt', 'Track::and::field_PROPN'),
#  (585, '/m/03ys48', 'Slovenia::national::football::team_PROPN'),
#  (587, '/m/03gqb0k', 'Ole::Miss::Rebels::football_PROPN'),
#  (588, '/m/015pdg', 'Southern::rock_PROPN'),
#  (590, '/m/04gxf', 'Lincoln,::Nebraska_PROPN'),
#  (591,
#   '/m/0b_6q5',
#   "1988::NCAA::Men's::Division::I::Basketball::Tournament_PROPN"),
#  (592,
#   '/m/0ds11z',
#   'Sweeney::Todd:::The::Demon::Barber::of::Fleet::Street::(2007::film)_PROPN'),
#  (593, '/m/02rjjll', '50th::Grammy::Awards_PROPN'),
#  (599, '/m/04f2zj', 'Multi-instrumentalist_PROPN'),
#  (601, '/m/04tz52', 'Popeye::(film)_PROPN'),
#  (603, '/m/025_64l', 'Tennessee::Volunteers::football_PROPN'),
#  (604, '/m/01_9c1', 'Defensive::back_PROPN'),
#  (605, '/m/05f4vxd', 'Glee::(TV::series)_PROPN'),
#  (609, '/m/0fd3y', 'Ambient::music_PROPN'),
#  (610, '/m/0m19t', 'Portishead::(band)_PROPN'),
#  (611, '/m/04v8x9', 'Ben-Hur::(1959::film)_PROPN'),
#  (612, '/m/0p9sw', 'Academy::Award::for::Best::Sound_PROPN'),
#  (613, '/m/02vs3x5', 'Re-recording::mixer_PROPN'),
#  (614, '/m/05t54s', 'Live::Free::or::Die::Hard_PROPN'),
#  (616, '/m/01tlmw', 'Norwalk,::Connecticut_PROPN'),
#  (618, '/m/06z6r', 'Swimming::(sport)_PROPN'),
#  (620, '/m/0ggx5q', 'Dance::music_PROPN'),
#  (621,
#   '/m/0bdwqv',
#   'Primetime::Emmy::Award::for::Outstanding::Lead::Actor::in::a::Miniseries::or::a::Movie_PROPN'),
#  (623, '/m/0g5qs2k', 'Snow::White::and::the::Huntsman_PROPN'),
#  (625, '/m/0j_t1', 'Nashville::(film)_PROPN'),
#  (628, '/m/02g3v6', 'Saturn::Award::for::Best::Costume_PROPN'),
#  (629, '/m/0ds33', 'Armageddon::(1998::film)_PROPN'),
#  (630,
#   '/m/02x4w6g',
#   'Independent::Spirit::Award::for::Best::Male::Lead_PROPN'),
#  (631, '/m/04zn7g', 'Chris::Penn_PROPN'),
#  (634, '/m/0dscrwf', 'The::Vow::(film)_PROPN'),
#  (636, '/m/01vrkdt', 'Wendy::Melvoin_PROPN'),
#  (638, '/m/02zsn', 'Female_PROPN'),
#  (641, '/m/016z5x', 'Chaplin::(film)_PROPN'),
#  (642, '/m/07f8wg', 'Mario::Kassar_PROPN'),
#  (644, '/m/0xhtw', 'Hard::rock_PROPN'),
#  (647, '/m/0dtfn', 'Star::Wars::Episode::IV:::A::New::Hope_PROPN'),
#  (649, '/m/01h7bb', 'The::Last::Samurai_PROPN'),
#  (651, '/m/02jknp', 'Film::director_PROPN'),
#  (656, '/m/019tzd', 'Mountain::biking_PROPN'),
#  (659, '/m/0b6tzs', 'No::Country::for::Old::Men::(film)_PROPN'),
#  (661, '/m/05hj0n', 'Kathleen::Quinlan_PROPN'),
#  (662, '/m/04lgymt', 'Phil::Tan_PROPN'),
#  (663, '/m/02g3gj', 'Grammy::Award::for::Best::Dance::Recording_PROPN'),
#  (671,
#   '/m/09v82c0',
#   'Primetime::Emmy::Award::for::Outstanding::Costumes::for::a::Miniseries,::Movie::or::a::Special_PROPN'),
#  (672, '/m/03cv_gy', 'John::Adams::(TV::miniseries)_PROPN'),
#  (673, '/m/06cs95', 'Into::the::West::(TV::miniseries)_PROPN'),
#  (675, '/m/02lhm2', 'Cedric::the::Entertainer_PROPN'),
#  (679, '/m/05qc_', 'Planet_PROPN'),
#  (682,
#   '/m/09sb52',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Cast::in::a::Motion::Picture_PROPN'),
#  (683, '/m/0gq6s3', 'Goya::Award::for::Best::Original::Screenplay_PROPN'),
#  (684, '/m/04nl83', 'The::Sea::Inside_PROPN'),
#  (685, '/m/0309lm', 'Stephen::Root_PROPN'),
#  (686, '/m/0wq3z', 'Gulfport,::Mississippi_PROPN'),
#  (687, '/m/02rgz4', 'Joe::Hisaishi_PROPN'),
#  (689,
#   '/m/0gkvb7',
#   'Primetime::Emmy::Award::for::Individual::Performance::in::a::Variety::or::Music::Program_PROPN'),
#  (691, '/m/07lmxq', 'Miguel::Sandoval_PROPN'),
#  (692, '/m/06jzh', 'Robin::Wright::(actress)_PROPN'),
#  (695, '/m/02q5bx2', 'Tin::Man::(TV::miniseries)_PROPN'),
#  (696,
#   '/m/07z2lx',
#   'Primetime::Emmy::Award::for::Outstanding::Miniseries_PROPN'),
#  (701, '/m/0gqy2', 'Academy::Award::for::Best::Supporting::Actor_PROPN'),
#  (702,
#   '/m/02vm9nd',
#   'Daytime::Emmy::Award::for::Outstanding::Game/Audience::Participation::Show_PROPN'),
#  (703, '/m/02qrv7', 'The::Living::Daylights_PROPN'),
#  (713, '/m/01ln5z', 'The::Mummy::(1999::film)_PROPN'),
#  (718, '/m/0n4m5', 'Buncombe::County,::North::Carolina_PROPN'),
#  (719, '/m/0ydpd', 'Asheville,::North::Carolina_PROPN'),
#  (720, '/m/02211by', 'Chief::technology::officer_PROPN'),
#  (721, '/m/01c6k4', 'Avid::Technology_PROPN'),
#  (723, '/m/03h_yy', 'The::Singing::Detective::(film)_PROPN'),
#  (725,
#   '/m/02gdjb',
#   'Grammy::Award::for::Best::Pop::Instrumental::Performance_PROPN'),
#  (726, '/m/05p1tzf', 'The::Hangover::(film)_PROPN'),
#  (727, '/m/0f830f', 'Robert::Clohessy_PROPN'),
#  (730, '/m/0dcqh', 'Multiple::sclerosis_PROPN'),
#  (731, '/m/01nqfh_', 'Brian::Tyler::(composer)_PROPN'),
#  (732, '/m/0bk1p', 'Queen::(band)_PROPN'),
#  (735, '/m/0mb8c', 'A::Better::Tomorrow_PROPN'),
#  (737,
#   '/m/01d38g',
#   'Grammy::Award::for::Best::R&B::Performance::by::a::Duo::or::Group::with::Vocals_PROPN'),
#  (738, '/m/06cc_1', 'Michael::McDonald::(singer)_PROPN'),
#  (739, '/m/02cg41', '46th::Grammy::Awards_PROPN'),
#  (740, '/m/03t5n3', 'Grammy::Award::for::Best::Rap::Song_PROPN'),
#  (742, '/m/060v34', 'House::of::Wax::(2005::film)_PROPN'),
#  (743, '/m/03npn', 'Horror::film_PROPN'),
#  (744, '/m/0bth54', 'Avatar::(2009::film)_PROPN'),
#  (746, '/m/02bxjp', 'Shōhei::Imamura_PROPN'),
#  (748, '/m/040vk98', 'Locus::Award::for::Best::Science::Fiction::Novel_PROPN'),
#  (750, '/m/0cb4j', 'Orange::County,::California_PROPN'),
#  (754, '/m/01sxly', 'A::Fish::Called::Wanda_PROPN'),
#  (755,
#   '/m/05zvj3m',
#   'MTV::Movie::Award::for::Best::Comedic::Performance_PROPN'),
#  (758, '/m/0d35y', 'Phoenix,::Arizona_PROPN'),
#  (759, '/m/0fz20l', '16th::Academy::Awards_PROPN'),
#  (760, '/m/0gqwc', 'Academy::Award::for::Best::Actress_PROPN'),
#  (762, '/m/0l98s', '1972::Summer::Olympics_PROPN'),
#  (764, '/m/050r1z', 'The::Last::of::the::Mohicans::(1992::film)_PROPN'),
#  (767, '/m/011yqc', 'L.A.::Confidential::(film)_PROPN'),
#  (768, '/m/0f4_2k', 'Angels::&::Demons::(film)_PROPN'),
#  (770,
#   '/m/02p_7cr',
#   'Daytime::Emmy::Award::for::Outstanding::Supporting::Actor::in::a::Drama::Series_PROPN'),
#  (771, '/m/02_1rq', 'Santa::Barbara::(TV::series)_PROPN'),
#  (772, '/m/02_1sj', 'EDtv_PROPN'),
#  (773, '/m/0g54xkt', 'J.::Edgar_PROPN'),
#  (775, '/m/0f4x7', 'Academy::Award::for::Best::Actor_PROPN'),
#  (776, '/m/0n0bp', 'Judgment::at::Nuremberg_PROPN'),
#  (778, '/m/02grdc', 'Grammy::Award::for::Best::Spoken::Word::Album_PROPN'),
#  (782, '/m/0b60sq', "Howl's::Moving::Castle::(film)_PROPN"),
#  (783, '/m/071h5c', 'Ben::Foster::(footballer)_PROPN'),
#  (784, '/m/0ggq0m', 'Classical::music_PROPN'),
#  (786, '/m/04ddm4', 'Jaws::3-D_PROPN'),
#  (787, '/m/02n4kr', 'Mystery::fiction_PROPN'),
#  (788, '/m/02825kb', 'Forgetting::Sarah::Marshall_PROPN'),
#  (789, '/m/0kbws', '2008::Summer::Olympics_PROPN'),
#  (790, '/m/03hr1p', 'Road::cycling_PROPN'),
#  (791,
#   '/m/0gr4k',
#   'Academy::Award::for::Best::Writing::(Adapted::Screenplay)_PROPN'),
#  (792, '/m/0bzk8w', '46th::Academy::Awards_PROPN'),
#  (793, '/m/03s6l2', 'Confessions::of::a::Dangerous::Mind_PROPN'),
#  (794, '/m/0lsxr', 'Crime::fiction_PROPN'),
#  (796, '/m/03ww_x', '96th::United::States::Congress_PROPN'),
#  (798, '/m/07_lq', 'Vegetarian::cuisine_PROPN'),
#  (799, '/m/02002f', 'Sinhala::language_PROPN'),
#  (802, '/m/02x3lt7', 'Hannah::Montana:::The::Movie_PROPN'),
#  (804, '/m/03xq0f', 'FilmFlex_PROPN'),
#  (805, '/m/08nvyr', 'Babel::(film)_PROPN'),
#  (806, '/m/019f4v', 'Golden::Globe::Award::for::Best::Director_PROPN'),
#  (808, '/m/0njlp', 'Ingham::County,::Michigan_PROPN'),
#  (811, '/m/0bq0p9', 'British::Raj_PROPN'),
#  (812, '/m/0xkq4', 'Englewood,::New::Jersey_PROPN'),
#  (816, '/m/011yph', 'The::Full::Monty_PROPN'),
#  (818,
#   '/m/09qwmm',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Female::Actor::in::a::Leading::Role_PROPN'),
#  (819, '/m/0fpkxfd', '2011::Sundance::Film::Festival_PROPN'),
#  (820, '/m/09v42sf', 'Kaboom::(film)_PROPN'),
#  (821,
#   '/m/0br1x_',
#   "2008::NCAA::Men's::Division::I::Basketball::Tournament_PROPN"),
#  (824, '/m/0fq27fp', 'Wuthering::Heights::(2011::film)_PROPN'),
#  (825, '/m/03kq98', 'Roots::(TV::miniseries)_PROPN'),
#  (827, '/m/0cpllql', 'Star::Wars:::The::Clone::Wars::(film)_PROPN'),
#  (828, '/m/02nxhr', 'Blu-ray::Disc_PROPN'),
#  (831, '/m/0dl5d', 'Progressive::rock_PROPN'),
#  (833, '/m/0ckd1', 'Executive::producer_PROPN'),
#  (834, '/m/0c40vxk', 'Haywire::(film)_PROPN'),
#  (836, '/m/02pp_q_', 'Jerry::Belson_PROPN'),
#  (837, '/m/0d4fqn', 'Jay::Kogen_PROPN'),
#  (838, '/m/02r22gf', 'BAFTA::Award::for::Best::Sound_PROPN'),
#  (839, '/m/01cssf', 'Romeo::+::Juliet_PROPN'),
#  (840, '/m/0298n7', 'Seabiscuit::(film)_PROPN'),
#  (843, '/m/06ryl', 'Saint::Kitts::and::Nevis_PROPN'),
#  (845, '/m/08720', 'WarGames_PROPN'),
#  (846, '/m/032t2z', 'Richard::Wright::(musician)_PROPN'),
#  (848, '/m/02q690_', '59th::Primetime::Emmy::Awards_PROPN'),
#  (850, '/m/028tv0', 'Lead::guitar_PROPN'),
#  (852, '/m/0127ps', 'Conspiracy::Theory::(film)_PROPN'),
#  (855, '/m/080nwsb', 'Footloose::(2011::film)_PROPN'),
#  (859, '/m/0dq_5', 'Chief::executive::officer_PROPN'),
#  (861, '/m/04n52p6', 'Sherlock::Holmes::(2009::film)_PROPN'),
#  (862, '/m/026p_bs', 'The::Prize::(1963::film)_PROPN'),
#  (866, '/m/02qvgy', 'Forward::(ice::hockey)_PROPN'),
#  (873, '/m/04jwjq', 'Veer-Zaara_PROPN'),
#  (877, '/m/013y1f', 'Organ::(music)_PROPN'),
#  (880, '/m/0401sg', 'Resident::Evil::(film)_PROPN'),
#  (882, '/m/01psyx', 'Renal::failure_PROPN'),
#  (883, '/m/0n22z', 'Lucas::County,::Ohio_PROPN'),
#  (885, '/m/0f4vx', 'Leaving::Las::Vegas_PROPN'),
#  (886, '/m/01pv51', 'Power::forward::(basketball)_PROPN'),
#  (888, '/m/0284n42', "Kevin::O'Connell::(sound::re-recording::mixer)_PROPN"),
#  (889, '/m/0pc62', 'Pearl::Harbor::(film)_PROPN'),
#  (891, '/m/0r0m6', 'Malibu,::California_PROPN'),
#  (893, '/m/03lygq', 'China::PR::national::football::team_PROPN'),
#  (896, '/m/0dqytn', 'The::Witches::of::Eastwick::(film)_PROPN'),
#  (897, '/m/064t9', 'Pop::music_PROPN'),
#  (899, '/m/0jcgs', 'Salt::Lake::County,::Utah_PROPN'),
#  (901, '/m/02jqjm', 'Toto::(band)_PROPN'),
#  (902, '/m/018vs', 'Bass::guitar_PROPN'),
#  (903, '/m/01pcdn', 'Kristin::Davis_PROPN'),
#  (904, '/m/0170_p', 'The::Hurricane::(1999::film)_PROPN'),
#  (905, '/m/033nzk', 'Chile::national::football::team_PROPN'),
#  (907, '/m/02pjc1h', 'In::Bruges_PROPN'),
#  (909,
#   '/m/0cqhk0',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::an::Ensemble::in::a::Comedy::Series_PROPN'),
#  (915, '/m/0g3zpp', '2007::NFL::Draft_PROPN'),
#  (916,
#   '/m/0bdw1g',
#   'Primetime::Emmy::Award::for::Outstanding::Lead::Actress::in::a::Drama::Series_PROPN'),
#  (917, '/m/039fgy', 'Thirtysomething::(TV::series)_PROPN'),
#  (918, '/m/05b1610', 'Golden::Raspberry::Award::for::Worst::Screenplay_PROPN'),
#  (919, '/m/0dj0m5', 'Christopher::Columbus:::The::Discovery_PROPN'),
#  (922, '/m/07mvp', 'The::Rolling::Stones_PROPN'),
#  (923, '/m/08c6k9', 'The::Fast::and::the::Furious:::Tokyo::Drift_PROPN'),
#  (924, '/m/0_b3d', 'In::the::Name::of::the::Father::(film)_PROPN'),
#  (925, '/m/026g4l_', 'Frederick::M.::Zollo_PROPN'),
#  (926, '/m/01l29r', 'Tony::Award::for::Best::Musical_PROPN'),
#  (927, '/m/0n5j7', 'Camden::County,::New::Jersey_PROPN'),
#  (928,
#   '/m/03176f',
#   "Harry::Potter::and::the::Philosopher's::Stone::(film)_PROPN"),
#  (929, '/m/06n7h7', 'Natalie::Morales_PROPN'),
#  (932,
#   '/m/09qvc0',
#   'Primetime::Emmy::Award::for::Outstanding::Guest::Actor::in::a::Comedy::Series_PROPN'),
#  (933, '/m/0fgpvf', 'Girl::with::a::Pearl::Earring::(film)_PROPN'),
#  (934, '/m/0209xj', 'Lost::in::Translation::(film)_PROPN'),
#  (937, '/m/0209hj', 'Gandhi::(film)_PROPN'),
#  (940, '/m/05kcgsf', '1965::Major::League::Baseball::season_PROPN'),
#  (942, '/m/01f8gz', 'Chungking::Express_PROPN'),
#  (943, '/m/01vvycq', 'Prince::(musician)_PROPN'),
#  (945, '/m/08phg9', 'Star::Trek::(film)_PROPN'),
#  (946, '/m/03rg2b', "In::Harm's::Way_PROPN"),
#  (948, '/m/01z9_x', 'Dr.::John_PROPN'),
#  (949,
#   '/m/0248jb',
#   'Grammy::Award::for::Best::Traditional::Blues::Album_PROPN'),
#  (950, '/m/07k53y', 'USC::Trojans::football_PROPN'),
#  (951, '/m/02vkdwz', 'Halfback::(American::football)_PROPN'),
#  (952, '/m/09q23x', "Charlie::Wilson's::War_PROPN"),
#  (953, '/m/020bv3', 'Love::Actually_PROPN'),
#  (954, '/m/02qggqc', 'Chris::Lebenzon_PROPN'),
#  (955, '/m/0fg04', 'Sleepy::Hollow::(film)_PROPN'),
#  (959, '/m/02qpbqj', 'Fullback::(gridiron::football)_PROPN'),
#  (965, '/m/02py4c8', 'Angels::in::America::(TV::miniseries)_PROPN'),
#  (968,
#   '/m/018wng',
#   'Academy::Award::for::Best::Documentary::(Short::Subject)_PROPN'),
#  (970, '/m/04fzfj', 'Godzilla::(1998::film)_PROPN'),
#  (972, '/m/0gs9p', 'Academy::Award::for::Best::Director_PROPN'),
#  (973, '/m/03cp4cn', 'Shutter::Island::(film)_PROPN'),
#  (974, '/m/01bgqh', 'Grammy::Award::for::Record::of::the::Year_PROPN'),
#  (975, '/m/01bx35', '43rd::Grammy::Awards_PROPN'),
#  (976, '/m/07s846j', 'The::Social::Network_PROPN'),
#  (977, '/m/0d2b38', 'Storyboard::artist_PROPN'),
#  (978, '/m/03h4fq7', 'Dinner::for::Schmucks_PROPN'),
#  (980, '/m/0p07_', 'Eagle::County,::Colorado_PROPN'),
#  (982, '/m/0mx4_', 'Linn::County,::Oregon_PROPN'),
#  (986, '/m/04306rv', 'German::language_PROPN'),
#  (990, '/m/04zx3q1', 'Doctor::of::Philosophy_PROPN'),
#  (991, '/m/065y4w7', 'Herman::Ostrow::School::of::Dentistry::of::USC_PROPN'),
#  (992,
#   '/m/03m73lj',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Stunt::Ensemble::in::a::Motion::Picture_PROPN'),
#  (993, '/m/061681', 'The::Bourne::Ultimatum::(film)_PROPN'),
#  (994, '/m/06w87', 'Steel::guitar_PROPN'),
#  (995, '/m/041ly3', 'Curtis::Armstrong_PROPN'),
#  (999, '/m/05qjt', 'Physics_PROPN'),
#  (1001, '/m/01vj9c', 'Bass::(instrument)_PROPN'),
#  (1003, '/m/04dn09n', 'Golden::Globe::Award::for::Best::Screenplay_PROPN'),
#  (1004, '/m/09q_6t', '56th::Golden::Globe::Awards_PROPN'),
#  (1006,
#   '/m/094qd5',
#   'BAFTA::Award::for::Best::Actress::in::a::Leading::Role_PROPN'),
#  (1007, '/m/026mfbr', 'Step::Brothers::(film)_PROPN'),
#  (1009, '/m/01hp5', 'Batman::(1989::film)_PROPN'),
#  (1010, '/m/0338lq', 'PolyGram::Filmed::Entertainment_PROPN'),
#  (1012, '/m/02z3r8t', 'New::York,::I::Love::You_PROPN'),
#  (1015,
#   '/m/09qj50',
#   'Primetime::Emmy::Award::for::Outstanding::Lead::Actress::in::a::Comedy::Series_PROPN'),
#  (1016, '/m/0kfpm', 'The::Mary::Tyler::Moore::Show_PROPN'),
#  (1017, '/m/043djx', '31st::United::States::Congress_PROPN'),
#  (1019, '/m/03gwpw2', 'Satellite::Awards::2007_PROPN'),
#  (1020, '/m/017gm7', 'The::Lord::of::the::Rings:::The::Two::Towers_PROPN'),
#  (1024, '/m/06s6l', 'Saint::Vincent::and::the::Grenadines_PROPN'),
#  (1025, '/m/01hp22', 'Artistic::gymnastics_PROPN'),
#  (1027, '/m/0dzfdw', 'Tony::Award::for::Best::Choreography_PROPN'),
#  (1028, '/m/01r97z', 'Striptease::(film)_PROPN'),
#  (1029, '/m/02w0dc0', 'Albert::Wolsky_PROPN'),
#  (1033, '/m/01qhm_', 'German::American_PROPN'),
#  (1035, '/m/0l998', '1968::Summer::Olympics_PROPN'),
#  (1036, '/m/0p_sc', 'Midnight::Express::(film)_PROPN'),
#  (1038, '/m/0kbvb', '2004::Summer::Olympics_PROPN'),
#  (1039, '/m/096f8', 'Show::jumping_PROPN'),
#  (1040,
#   '/m/02f6ym',
#   'MTV::Video::Music::Award::for::Best::Female::Video_PROPN'),
#  (1044, '/m/0glb5', 'Brittany::(administrative::region)_PROPN'),
#  (1046,
#   '/m/099t8j',
#   'Broadcast::Film::Critics::Association::Award::for::Best::Supporting::Actress_PROPN'),
#  (1048, '/m/0bzm__', '56th::Academy::Awards_PROPN'),
#  (1049, '/m/01qzyz', 'Twelve-string::guitar_PROPN'),
#  (1050, '/m/0gkz15s', 'The::Hunger::Games::(film::project)_PROPN'),
#  (1051, '/m/02k_4g', 'The::Practice_PROPN'),
#  (1052,
#   '/m/0fbvqf',
#   'Primetime::Emmy::Award::for::Outstanding::Supporting::Actor::in::a::Drama::Series_PROPN'),
#  (1053, '/m/018ctl', '2010::Winter::Olympics_PROPN'),
#  (1054, '/m/0cj16', '35::mm::film_PROPN'),
#  (1055, '/m/02ryz24', 'Tropic::Thunder_PROPN'),
#  (1056, '/m/03hjv97', 'The::Merry::Widow::(1934::film)_PROPN'),
#  (1057, '/m/076lxv', 'Edwin::B.::Willis_PROPN'),
#  (1061, '/m/0lpp8', 'Burgundy::(French::region)_PROPN'),
#  (1065, '/m/035xwd', 'Sleepers::(film)_PROPN'),
#  (1066, '/m/09p35z', 'Starter::for::10::(film)_PROPN'),
#  (1067, '/m/0415svh', 'Gary::Goetzman_PROPN'),
#  (1069, '/m/024tcq', '108th::United::States::Congress_PROPN'),
#  (1073, '/m/02vxfw_', 'Supervising::Sound::Editor_PROPN'),
#  (1074, '/m/09zf_q', 'The::Time::Machine::(2002::film)_PROPN'),
#  (1076, '/m/03hkch7', 'Milk::(film)_PROPN'),
#  (1077,
#   '/m/03hl6lc',
#   'Writers::Guild::of::America::Award::for::Best::Original::Screenplay_PROPN'),
#  (1083, '/m/03ckwzc', 'Miracle::at::St.::Anna_PROPN'),
#  (1085, '/m/07z31v', '56th::Primetime::Emmy::Awards_PROPN'),
#  (1086,
#   '/m/0bdw6t',
#   'Primetime::Emmy::Award::for::Outstanding::Lead::Actor::in::a::Drama::Series_PROPN'),
#  (1088, '/m/07hpv3', 'The::Boondocks::(TV::series)_PROPN'),
#  (1089, '/m/0vgkd', 'Black::comedy_PROPN'),
#  (1090, '/m/0vrmb', 'Dearborn,::Michigan_PROPN'),
#  (1091, '/m/0cbv4g', 'The::Devil::Wears::Prada::(film)_PROPN'),
#  (1092,
#   '/m/03hj5vf',
#   'Broadcast::Film::Critics::Association::Award::for::Best::Comedy::Film_PROPN'),
#  (1093, '/m/0jzw', 'Apocalypse::Now_PROPN'),
#  (1094, '/m/03k9fj', 'Adventure::film_PROPN'),
#  (1095, '/m/01jfsb', 'Thriller::(genre)_PROPN'),
#  (1096, '/m/0dsvzh', 'Gone::Baby::Gone_PROPN'),
#  (1097, '/m/084qpk', 'Grindhouse::(film)_PROPN'),
#  (1101, '/m/0785v8', 'John::Hawkes::(actor)_PROPN'),
#  (1104, '/m/09jwl', 'Musician_PROPN'),
#  (1105, '/m/01qkqwg', 'Jake::Shimabukuro_PROPN'),
#  (1106, '/m/02hxhz', 'Big::Daddy::(film)_PROPN'),
#  (1109, '/m/07rhpg', 'Lesley::Sharp_PROPN'),
#  (1110, '/m/0b73_1d', 'True::Grit::(2010::film)_PROPN'),
#  (1118, '/m/02773m2', 'John::Riggi_PROPN'),
#  (1119, '/m/02778pf', 'Marci::Klein_PROPN'),
#  (1120, '/m/0pv2t', 'The::Goodbye::Girl_PROPN'),
#  (1121,
#   '/m/027986c',
#   'Los::Angeles::Film::Critics::Association::Award::for::Best::Actor_PROPN'),
#  (1122, '/m/0164qt', 'The::World::Is::Not::Enough_PROPN'),
#  (1123, '/m/02sg5v', 'A::View::to::a::Kill_PROPN'),
#  (1124, '/m/016jhr', 'Jam::band_PROPN'),
#  (1126, '/m/0bs5k8r', "Mao's::Last::Dancer::(film)_PROPN"),
#  (1130, '/m/060d2', 'President::of::the::United::States_PROPN'),
#  (1131, '/m/02lfl4', 'Tony::Sirico_PROPN'),
#  (1132, '/m/0521rl1', 'Matt::Servitto_PROPN'),
#  (1137, '/m/07p__7', '109th::United::States::Congress_PROPN'),
#  (1139, '/m/013n2h', 'Midland,::Texas_PROPN'),
#  (1140, '/m/02q_cc', 'Kathleen::Kennedy::(film::producer)_PROPN'),
#  (1143, '/m/066m4g', 'T.::R.::Knight_PROPN'),
#  (1144, '/m/071t0', 'Shooting::sport_PROPN'),
#  (1145, '/m/09x3r', '1936::Summer::Olympics_PROPN'),
#  (1146, '/m/02z13jg', 'Best::Actor::Award::(Cannes::Film::Festival)_PROPN'),
#  (1149, '/m/0_3cs', 'Allentown,::Pennsylvania_PROPN'),
#  (1150, '/m/0mwl2', 'Lehigh::County,::Pennsylvania_PROPN'),
#  (1152, '/m/06_wqk4', "Valentine's::Day::(film)_PROPN"),
#  (1153, '/m/013kcv', 'Tulsa,::Oklahoma_PROPN'),
#  (1156, '/m/02h4rq6', 'Bachelor::of::Science_PROPN'),
#  (1157, '/m/0dhrqx', 'Ben::Sahar_PROPN'),
#  (1158, '/m/05jzt3', 'Walk::the::Line_PROPN'),
#  (1161, '/m/0ccd3x', 'West::Side::Story::(film)_PROPN'),
#  (1162, '/m/03r8tl', 'Filmfare::Award::for::Best::Actor_PROPN'),
#  (1168, '/m/01_gx_', 'Yorkshire::Terrier_PROPN'),
#  (1169, '/m/0f04v', 'San::Jose,::California_PROPN'),
#  (1170, '/m/0l6ny', '1984::Summer::Olympics_PROPN'),
#  (1173, '/m/02z9hqn', 'Evangelion:::2.0::You::Can::(Not)::Advance_PROPN'),
#  (1174, '/m/06mfvc', 'Ben::Foster::(actor)_PROPN'),
#  (1175,
#   '/m/0ck27z',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::an::Ensemble::in::a::Drama::Series_PROPN'),
#  (1176,
#   '/m/09qv3c',
#   'Primetime::Emmy::Award::for::Outstanding::Supporting::Actor::in::a::Comedy::Series_PROPN'),
#  (1178, '/m/0152cw', 'Jewel::(singer)_PROPN'),
#  (1180, '/m/03bwzr4', 'Master::of::Science_PROPN'),
#  (1181, '/m/09vw2b7', 'Special::effects::supervisor_PROPN'),
#  (1183, '/m/08w7vj', 'Stephen::Graham::(actor)_PROPN'),
#  (1185, '/m/06z8s_', "Ocean's::Eleven::(2001::film)_PROPN"),
#  (1186, '/m/0dky9n', 'Ralph::E.::Winters_PROPN'),
#  (1187, '/m/0147sh', 'Quo::Vadis::(1951::film)_PROPN'),
#  (1189,
#   '/m/0cqh46',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Male::Actor::in::a::Miniseries::or::Television::Movie_PROPN'),
#  (1191,
#   '/m/047byns',
#   'Primetime::Emmy::Award::for::Outstanding::Writing::for::a::Variety,::Music::or::Comedy::Program_PROPN'),
#  (1192, '/m/0287477', 'Wanted::(2008::film)_PROPN'),
#  (1194, '/m/0dwtp', 'Glockenspiel_PROPN'),
#  (1196, '/m/04tc1g', 'The::Adventures::of::Pluto::Nash_PROPN'),
#  (1197, '/m/0b13yt', 'Dimeback_PROPN'),
#  (1201, '/m/043h78', 'Scooby-Doo::(film)_PROPN'),
#  (1204, '/m/069ld1', 'Desmond::Harrington_PROPN'),
#  (1206, '/m/04b4yg', 'Sierra::Leone::national::football::team_PROPN'),
#  (1210, '/m/0ymbl', "St::Catherine's::College,::Oxford_PROPN"),
#  (1214, '/m/02vjzr', 'Adult::contemporary::music_PROPN'),
#  (1215, '/m/016vh2', 'Caper::story_PROPN'),
#  (1216, '/m/03wbqc4', 'The::Taking::of::Pelham::123::(2009::film)_PROPN'),
#  (1219, '/m/0344gc', "Monster's::Ball_PROPN"),
#  (1220,
#   '/m/02x1dht',
#   'Satellite::Award::for::Best::Original::Screenplay_PROPN'),
#  (1223, '/m/04969y', 'Some::Kind::of::Monster::(film)_PROPN'),
#  (1224,
#   '/m/02f72_',
#   'MTV::Video::Music::Award::for::Best::Art::Direction_PROPN'),
#  (1229,
#   '/m/01vksx',
#   'Pirates::of::the::Caribbean:::The::Curse::of::the::Black::Pearl_PROPN'),
#  (1230, '/m/07fb8_', 'Super::35_PROPN'),
#  (1232, '/m/0265v21', 'Patrick::Mulcahey_PROPN'),
#  (1233, '/m/026dg51', 'Courtney::Simon_PROPN'),
#  (1234,
#   '/m/02qrbbx',
#   'Genie::Award::for::Best::Achievement::in::Cinematography_PROPN'),
#  (1235, '/m/01srq2', 'Naked::Lunch::(film)_PROPN'),
#  (1239, '/m/05zr0xl', 'Modern::Family_PROPN'),
#  (1241, '/m/065b6q', 'Swedish::American_PROPN'),
#  (1243, '/m/03cvwkr', "Tough::Guys::Don't::Dance::(film)_PROPN"),
#  (1245,
#   '/m/02cttt',
#   'University::at::Buffalo,::The::State::University::of::New::York_PROPN'),
#  (1246, '/m/04sx9_', 'Peter::Riegert_PROPN'),
#  (1248, '/m/0ddd9', 'Nobel::Prize::in::Literature_PROPN'),
#  (1250, '/m/039c26', 'Deadwood::(TV::series)_PROPN'),
#  (1251, '/m/050rj', 'Musical::saw_PROPN'),
#  (1252,
#   '/m/05p1dby',
#   'Golden::Raspberry::Award::for::Worst::Prequel,::Remake,::Rip-off::or::Sequel_PROPN'),
#  (1254, '/m/03t97y', 'The::Mummy::Returns_PROPN'),
#  (1255, '/m/02rcdc2', 'The::Diving::Bell::and::the::Butterfly::(film)_PROPN'),
#  (1256, '/m/04gknr', 'Rules::of::Engagement::(film)_PROPN'),
#  (1259, '/m/0sxmx', 'Platoon::(film)_PROPN'),
#  (1260, '/m/06r_by', 'Robert::Richardson::(cinematographer)_PROPN'),
#  (1262, '/m/0bn9sc', 'Brad::Jones::(footballer)_PROPN'),
#  (1263, '/m/02279c', 'Rotherham::United::F.C._PROPN'),
#  (1265,
#   '/m/0b_6rk',
#   "1990::NCAA::Men's::Division::I::Basketball::Tournament_PROPN"),
#  (1266, '/m/027rwmr', 'Michael::Lantieri_PROPN'),
#  (1267, '/m/03h26tm', 'Ken::Ralston_PROPN'),
#  (1268, '/m/02qflgv', 'Joanne::Froggatt_PROPN'),
#  (1270, '/m/0r5y9', 'San::Mateo,::California_PROPN'),
#  (1272, '/m/05fm6m', 'Bewitched::(film)_PROPN'),
#  (1276, '/m/01qb5d', 'X2::(film)_PROPN'),
#  (1278, '/m/04n6k', 'Library::of::Congress::Classification_PROPN'),
#  (1279, '/m/026ldz7', 'Arizona::State::Sun::Devils::football_PROPN'),
#  (1280, '/m/05zm34', 'Punter::(football)_PROPN'),
#  (1281, '/m/01vdm0', 'Electronic::keyboard_PROPN'),
#  (1287, '/m/092vkg', 'Capote::(film)_PROPN'),
#  (1289, '/m/0963mq', 'She::Hate::Me_PROPN'),
#  (1292, '/m/02wzl1d', '65th::Golden::Globe::Awards_PROPN'),
#  (1293, '/m/01hhvg', 'University::of::California,::Riverside_PROPN'),
#  (1298, '/m/0cwy47', 'Cleopatra::(1963::film)_PROPN'),
#  (1305,
#   '/m/02z1nbg',
#   'National::Board::of::Review::Award::for::Best::Actress_PROPN'),
#  (1306, '/m/09z2b7', 'The::Wings::of::the::Dove::(1997::film)_PROPN'),
#  (1307, '/m/0r62v', 'Santa::Barbara,::California_PROPN'),
#  (1308, '/m/0kcd5', 'TNT::(TV::channel)_PROPN'),
#  (1309, '/m/05ztrmj', 'MTV::Movie::Award::for::Best::Fight_PROPN'),
#  (1315, '/m/0gg5qcw', 'The::Ides::of::March::(film)_PROPN'),
#  (1316, '/m/04f525m', 'Summit::Entertainment_PROPN'),
#  (1317, '/m/0fh694', 'Michael::Clayton::(film)_PROPN'),
#  (1321, '/m/03j755', 'APOEL::F.C._PROPN'),
#  (1322, '/m/01s0ps', 'Electric::piano_PROPN'),
#  (1324, '/m/012t_z', 'Businessperson_PROPN'),
#  (1329,
#   '/m/017gl1',
#   'The::Lord::of::the::Rings:::The::Fellowship::of::the::Ring_PROPN'),
#  (1332, '/m/02qzmz6', 'Sliver::(film)_PROPN'),
#  (1335, '/m/04kkz8', 'Patch::Adams::(film)_PROPN'),
#  (1336, '/m/04l3_z', 'Steve::Oedekerk_PROPN'),
#  (1339, '/m/0glyyw', 'Bruce::Berman_PROPN'),
#  (1340, '/m/0dlngsd', 'Sherlock::Holmes:::A::Game::of::Shadows_PROPN'),
#  (1341, '/m/03y_f8', 'Serbia::national::football::team_PROPN'),
#  (1344, '/m/01bdxz', 'Torquay::United::F.C._PROPN'),
#  (1346, '/m/03lfd_', 'Napoleon::Dynamite_PROPN'),
#  (1347,
#   '/m/02x8n1n',
#   'Independent::Spirit::Award::for::Best::Supporting::Male_PROPN'),
#  (1348, '/m/01d3n8', 'Internal::medicine_PROPN'),
#  (1349, '/m/0hgxh', 'Jaundice_PROPN'),
#  (1350, '/m/02_sr1', 'Rush::Hour::2_PROPN'),
#  (1352, '/m/08jbxf', 'Jade::North_PROPN'),
#  (1353, '/m/0d1pc', 'Model::(person)_PROPN'),
#  (1355, '/m/0l2lk', 'Monterey::County,::California_PROPN'),
#  (1357, '/m/0m_mm', 'Giant::(1956::film)_PROPN'),
#  (1362, '/m/0mw89', 'Westmoreland::County,::Pennsylvania_PROPN'),
#  (1363, '/m/0mw93', 'Washington::County,::Pennsylvania_PROPN'),
#  (1365, '/m/03mqj_', 'FC::Rubin::Kazan_PROPN'),
#  (1366, '/m/0p9lw', 'Dogma::(film)_PROPN'),
#  (1367,
#   '/m/099tbz',
#   'Broadcast::Film::Critics::Association::Award::for::Best::Cast_PROPN'),
#  (1368, '/m/0dn16', 'Bubblegum::pop_PROPN'),
#  (1369, '/m/07qnf', 'The::Monkees_PROPN'),
#  (1372, '/m/01dtl', 'Bristol::City::F.C._PROPN'),
#  (1373,
#   '/m/023vrq',
#   'Grammy::Award::for::Best::Rap::Performance::by::a::Duo::or::Group_PROPN'),
#  (1374, '/m/01wyz92', "Lil'::Kim_PROPN"),
#  (1375, '/m/015ynm', 'Lilo::&::Stitch_PROPN'),
#  (1377, '/m/01m1dzc', 'Norman::Blake::(American::musician)_PROPN'),
#  (1378, '/m/013b2h', '44th::Grammy::Awards_PROPN'),
#  (1379, '/m/0yfvf', 'Fayetteville,::North::Carolina_PROPN'),
#  (1384, '/m/06krf3', 'Mommie::Dearest::(film)_PROPN'),
#  (1385, '/m/03c7tr1', 'Golden::Raspberry::Award::for::Worst::Actress_PROPN'),
#  (1386, '/m/05zvq6g', 'European::Film::Award::for::Best::Actress_PROPN'),
#  (1387, '/m/01m13b', 'Dancer::in::the::Dark_PROPN'),
#  (1392, '/m/03qbnj', 'Grammy::Award::for::Best::Pop::Vocal::Album_PROPN'),
#  (1395, '/m/0gr42', 'Academy::Award::for::Best::Visual::Effects_PROPN'),
#  (1397, '/m/0bwfwpj', 'Super::8::(film)_PROPN'),
#  (1398, '/m/06n90', 'Science::fiction_PROPN'),
#  (1399, '/m/0jtdp', 'Documentary::film_PROPN'),
#  (1406, '/m/0124jj', 'Perth::and::Kinross_PROPN'),
#  (1407, '/m/0g133', 'Perth,::Scotland_PROPN'),
#  (1408, '/m/0dgq80b', 'Ghost::Rider:::Spirit::of::Vengeance_PROPN'),
#  (1409,
#   '/m/0crfwmx',
#   'Tinker::Bell::and::the::Mysterious::Winter::Woods_PROPN'),
#  (1411, '/m/0cskb', 'Buffy::the::Vampire::Slayer::(TV::series)_PROPN'),
#  (1415, '/m/0c7g7', 'World::Heritage::Site_PROPN'),
#  (1419, '/m/0dsfnd', 'Beijing::Guoan::F.C._PROPN'),
#  (1420, '/m/0czmk1', 'Ross::Turnbull_PROPN'),
#  (1421, '/m/01x4wq', 'Barnsley::F.C._PROPN'),
#  (1423, '/m/02bn_p', '106th::United::States::Congress_PROPN'),
#  (1424, '/m/032ft5', '94th::United::States::Congress_PROPN'),
#  (1425, '/m/071pf2', 'Scott::McDonald_PROPN'),
#  (1427, '/m/02l7c8', 'Romance::film_PROPN'),
#  (1428, '/m/011ykb', 'Jerry::Maguire_PROPN'),
#  (1435, '/m/0jkvj', '1976::Summer::Olympics_PROPN'),
#  (1436, '/m/03vfr_', 'The::SpongeBob::SquarePants::Movie_PROPN'),
#  (1437, '/m/01x0sy', 'Bill::Fagerbakke_PROPN'),
#  (1438, '/m/01p5_g', 'Pin-up::girl_PROPN'),
#  (1439, '/m/07_fj54', 'Marmaduke::(film)_PROPN'),
#  (1440, '/m/010v8k', 'Spokane,::Washington_PROPN'),
#  (1442, '/m/04hpck', 'Treat::Williams_PROPN'),
#  (1443, '/m/04pm6', 'Linux::kernel_PROPN'),
#  (1444, '/m/05khh', 'Operating::system_PROPN'),
#  (1445, '/m/0sqc8', 'Lafayette,::Indiana_PROPN'),
#  (1446,
#   '/m/027b9j5',
#   'London::Film::Critics::Circle::Award::for::Actor::of::the::Year_PROPN'),
#  (1447, '/m/011yl_', 'Shine::(film)_PROPN'),
#  (1449, '/m/01zq91', 'Finance::minister_PROPN'),
#  (1451, '/m/08cn_n', 'Joe::Berlinger_PROPN'),
#  (1452, '/m/05pcn59', 'MTV::Movie::Award::for::Best::Kiss_PROPN'),
#  (1454, '/m/08hmch', 'X-Men::Origins:::Wolverine_PROPN'),
#  (1456, '/m/09_bl', 'Short::track::speed::skating_PROPN'),
#  (1457, '/m/05q96q6', 'Robin::Hood::(2010::film)_PROPN'),
#  (1459, '/m/06196', 'Prometheus::Award_PROPN'),
#  (1461, '/m/0bz5v2', 'John::Oliver::(comedian)_PROPN'),
#  (1462, '/m/03gjzk', 'Television::producer_PROPN'),
#  (1464, '/m/05pcjw', 'Private::university_PROPN'),
#  (1469, '/m/07bzz7', 'Yellow::Submarine::(film)_PROPN'),
#  (1470, '/m/02qm_f', 'The::Incredibles_PROPN'),
#  (1472, '/m/048scx', 'Thirteen::Days::(film)_PROPN'),
#  (1473, '/m/02hxc3j', 'Romanian::language_PROPN'),
#  (1476, '/m/0pv3x', 'The::English::Patient::(film)_PROPN'),
#  (1478, '/m/0gqzz', 'Academy::Award::for::Best::Animated::Feature_PROPN'),
#  (1482,
#   '/m/02q1tc5',
#   'Daytime::Emmy::Award::for::Outstanding::Drama::Series::Writing::Team_PROPN'),
#  (1483, '/m/05qsxy', 'Wisner::Washam_PROPN'),
#  (1485, '/m/06by7', 'Rock::music_PROPN'),
#  (1487,
#   '/m/086vfb',
#   'Tony::Award::for::Best::Featured::Actress::in::a::Musical_PROPN'),
#  (1488, '/m/021_rm', 'Robert::Iler_PROPN'),
#  (1489, '/m/02r3zy', 'Foo::Fighters_PROPN'),
#  (1490, '/m/0264v8r', '1.::FC::Union::Berlin_PROPN'),
#  (1494, '/m/0mq17', 'Tarrant::County,::Texas_PROPN'),
#  (1495,
#   '/m/02rdxsh',
#   'National::Society::of::Film::Critics::Award::for::Best::Film_PROPN'),
#  (1497, '/m/0bshwmp', 'Just::Go::with::It_PROPN'),
#  (1499, '/m/018f8', 'Blazing::Saddles_PROPN'),
#  (1501, '/m/02vjp3', 'Sky::Captain::and::the::World::of::Tomorrow_PROPN'),
#  (1502, '/m/01wtlq', 'Contemporary::classical::music_PROPN'),
#  (1504, '/m/0jqp3', 'Easy::Rider_PROPN'),
#  (1506, '/m/02d44q', 'In::America::(film)_PROPN'),
#  (1507, '/m/01_mdl', 'Superman::(film)_PROPN'),
#  (1514, '/m/0f3zf_', 'Dean::Cundey_PROPN'),
#  (1515, '/m/0k2sk', 'Who::Framed::Roger::Rabbit_PROPN'),
#  (1516, '/m/09q5w2', 'Gladiator::(2000::film)_PROPN'),
#  (1517, '/m/089fss', 'Set::decorator_PROPN'),
#  (1518, '/m/0l8z1', 'Academy::Award::for::Best::Original::Score_PROPN'),
#  (1519, '/m/01c22t', 'Monsters,::Inc._PROPN'),
#  (1520, '/m/0l6m5', '1992::Summer::Olympics_PROPN'),
#  (1521, '/m/0171lb', 'George::Seaton_PROPN'),
#  (1522, '/m/0ktx_', 'Miracle::on::34th::Street_PROPN'),
#  (1524, '/m/0jm_', 'American::football_PROPN'),
#  (1526, '/m/02yw5r', '72nd::Academy::Awards_PROPN'),
#  (1528, '/m/0dy68h', 'Angers::SCO_PROPN'),
#  (1530, '/m/03x3wf', 'Grammy::Lifetime::Achievement::Award_PROPN'),
#  (1532, '/m/01fjz9', 'Motherwell::F.C._PROPN'),
#  (1533, '/m/06sy4c', 'John::Ruddy_PROPN'),
#  (1540, '/m/01mc11', 'Poughkeepsie,::New::York_PROPN'),
#  (1541, '/m/0gkkf', 'Jesus::College,::Cambridge_PROPN'),
#  (1542, '/m/01nv4h', 'Pound::sterling_PROPN'),
#  (1547, '/m/07bdd_', 'Golden::Raspberry::Award::for::Worst::Picture_PROPN'),
#  (1548, '/m/0wh3', 'Ann::Arbor,::Michigan_PROPN'),
#  (1549, '/m/0jjy0', 'Signs::(film)_PROPN'),
#  (1550, '/m/02f716', 'MTV::Video::Music::Award::for::Best::Direction_PROPN'),
#  (1551, '/m/0dw4g', 'U2_PROPN'),
#  (1553, '/m/0yc84', 'New::Rochelle,::New::York_PROPN'),
#  (1554,
#   '/m/0cqh6z',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Female::Actor::in::a::Drama::Series_PROPN'),
#  (1555, '/m/09qvms', '12th::Screen::Actors::Guild::Awards_PROPN'),
#  (1556, '/m/047g8h', 'Placekicker_PROPN'),
#  (1558, '/m/06b0d2', 'Mehcad::Brooks_PROPN'),
#  (1562, '/m/0mwx6', 'Cambria::County,::Pennsylvania_PROPN'),
#  (1564, '/m/05nmg_', 'Raja::CA::Casablanca_PROPN'),
#  (1565, '/m/06wcbk7', 'Universal::Motown_PROPN'),
#  (1567, '/m/02q8ms8', 'The::Brothers::Bloom_PROPN'),
#  (1573, '/m/0jyx6', 'Manhattan::(film)_PROPN'),
#  (1575,
#   '/m/0bdwft',
#   'Primetime::Emmy::Award::for::Outstanding::Lead::Actress::in::a::Miniseries::or::a::Movie_PROPN'),
#  (1576, '/m/0c5dd', 'It::Happened::One::Night_PROPN'),
#  (1578, '/m/0t_07', 'Concord,::Massachusetts_PROPN'),
#  (1579, '/m/0jnwx', 'Aladdin::(1992::Disney::film)_PROPN'),
#  (1580, '/m/018wdw', 'Academy::Award::for::Best::Sound::Editing_PROPN'),
#  (1581, '/m/04vr_f', 'The::Departed_PROPN'),
#  (1583, '/m/016r9z', '1900::Summer::Olympics_PROPN'),
#  (1584, '/m/0bl06', 'The::Greatest::Show::on::Earth_PROPN'),
#  (1585, '/m/057bc6m', 'Ray::Moyer_PROPN'),
#  (1586, '/m/02bqn1', '102nd::United::States::Congress_PROPN'),
#  (1588, '/m/01gjd0', 'First::Indochina::War_PROPN'),
#  (1590,
#   '/m/02w_6xj',
#   'Los::Angeles::Film::Critics::Association::Award::for::Best::Director_PROPN'),
#  (1593, '/m/012x1l', 'Pretenders::(band)_PROPN'),
#  (1595, '/m/03bxz7', 'Biographical::film_PROPN'),
#  (1596, '/m/02r8hh_', 'Persepolis::(film)_PROPN'),
#  (1598, '/m/02qjv', 'Electronic::musical::instrument_PROPN'),
#  (1600, '/m/02qyntr', 'BAFTA::Award::for::Best::Editing_PROPN'),
#  (1601, '/m/0249kn', 'Nitty::Gritty::Dirt::Band_PROPN'),
#  (1603, '/m/0p_th', 'Kramer::vs.::Kramer_PROPN'),
#  (1608, '/m/0ym8f', "The::Queen's::College,::Oxford_PROPN"),
#  (1609, '/m/02lp1', 'Electrical::engineering_PROPN'),
#  (1615, '/m/02x2khw', '2003::Major::League::Baseball::Draft_PROPN'),
#  (1616,
#   '/m/099c8n',
#   'Broadcast::Film::Critics::Association::Award::for::Best::Film_PROPN'),
#  (1618, '/m/01pvkk', 'Sound::editor_PROPN'),
#  (1619, '/m/05pxnmb', 'Imagine::That::(film)_PROPN'),
#  (1620, '/m/02w9895', 'Siobhan::Finneran_PROPN'),
#  (1621, '/m/0d7wh', 'British::people_PROPN'),
#  (1622, '/m/03cp7b3', 'William::Chang_PROPN'),
#  (1626, '/m/0swff', '1994::Winter::Olympics_PROPN'),
#  (1627, '/m/02lfns', 'Dominic::Chianese_PROPN'),
#  (1628, '/m/01qdmh', 'Spy::Game_PROPN'),
#  (1629, '/m/09gdm7q', 'The::Whistleblower_PROPN'),
#  (1631, '/m/0k3gw', 'Bristol::County,::Massachusetts_PROPN'),
#  (1632, '/m/0tyww', 'Taunton,::Massachusetts_PROPN'),
#  (1633, '/m/0872p_c', 'Transformers:::Dark::of::the::Moon_PROPN'),
#  (1635, '/m/02_5h', 'Figure::skating_PROPN'),
#  (1638, '/m/0g48m4', 'Lebanese::American_PROPN'),
#  (1642, '/m/053rxgm', 'The::Expendables::(2010::film)_PROPN'),
#  (1644, '/m/02scbv', 'Rambo:::First::Blood::Part::II_PROPN'),
#  (1645, '/m/0cp0t91', 'On::the::Road::(film)_PROPN'),
#  (1647, '/m/05m883', 'Jim::Taylor::(writer)_PROPN'),
#  (1648, '/m/02n9nmz', 'BAFTA::Award::for::Best::Adapted::Screenplay_PROPN'),
#  (1653, '/m/06rv5t', 'PAS::Giannina::F.C._PROPN'),
#  (1654, '/m/02v63m', 'Scream::3_PROPN'),
#  (1656, '/m/02dwj', 'Dr.::Strangelove_PROPN'),
#  (1657, '/m/043tz8m', 'Oklahoma::State::Cowboys::football_PROPN'),
#  (1660, '/m/04nfpk', 'Defensive::end_PROPN'),
#  (1661, '/m/033g4d', 'Lethal::Weapon::4_PROPN'),
#  (1662, '/m/05h4t7', 'Silver::Pictures_PROPN'),
#  (1665, '/m/06gb2q', 'Larry::Miller::(entertainer)_PROPN'),
#  (1667, '/m/02pkpfs', 'Allen::Leech_PROPN'),
#  (1669, '/m/07sc6nw', 'Sucker::Punch::(film)_PROPN'),
#  (1671, '/m/0283ph', 'Ghost::in::the::Shell:::Stand::Alone::Complex_PROPN'),
#  (1672, '/m/092c5f', '10th::Screen::Actors::Guild::Awards_PROPN'),
#  (1678, '/m/02pqp12', 'BAFTA::Award::for::Best::Direction_PROPN'),
#  (1679, '/m/048yqf', 'Elektra::(2005::film)_PROPN'),
#  (1683, '/m/016t_3', "Master's::degree_PROPN"),
#  (1685, '/m/0n6ds', 'Cruel::Intentions_PROPN'),
#  (1687, '/m/0gj8t_b', 'Rock::of::Ages::(film)_PROPN'),
#  (1691, '/m/01vrt_c', 'Pink::(singer)_PROPN'),
#  (1694, '/m/0glqh5_', 'Contraband::(2012::film)_PROPN'),
#  (1697, '/m/0988cp', 'Glen::Charles_PROPN'),
#  (1699, '/m/0d3f83', 'Hameur::Bouazza_PROPN'),
#  (1701, '/m/07gbf', 'Twin::Peaks_PROPN'),
#  (1705, '/m/0gjk1d', 'Dead::Man::Walking::(film)_PROPN'),
#  (1711, '/m/0fvxz', 'Trenton,::New::Jersey_PROPN'),
#  (1712,
#   '/m/025m98',
#   'Grammy::Award::for::Best::Instrumental::Composition_PROPN'),
#  (1713, '/m/0fm2_', 'Kingston::upon::Hull_PROPN'),
#  (1714, '/m/02prw4h', 'Talk::to::Me::(2007::film)_PROPN'),
#  (1715, '/m/03bx2lk', 'G-Force::(film)_PROPN'),
#  (1720, '/m/07gkgp', 'Michael::Dobson::(actor)_PROPN'),
#  (1721, '/m/02rhwjr', 'Mobile::Suit::Gundam::00_PROPN'),
#  (1722,
#   '/m/020fcn',
#   'Master::and::Commander:::The::Far::Side::of::the::World_PROPN'),
#  (1724, '/m/0t_gg', 'Quincy,::Massachusetts_PROPN'),
#  (1725, '/m/0kpys', 'Los::Angeles::County,::California_PROPN'),
#  (1726, '/m/0r111', 'Torrance,::California_PROPN'),
#  (1727, '/m/011yg9', 'Sense::and::Sensibility::(film)_PROPN'),
#  (1728, '/m/026g73', 'Bongo::drum_PROPN'),
#  (1730, '/m/0r1yc', 'Carmel-by-the-Sea,::California_PROPN'),
#  (1731, '/m/05z_kps', 'Fish::Tank::(film)_PROPN'),
#  (1733, '/m/026390q', 'Thelma::&::Louise_PROPN'),
#  (1735, '/m/0c4z8', 'Grammy::Award::for::Song::of::the::Year_PROPN'),
#  (1737, '/m/01sn04', 'Jamaica,::Queens_PROPN'),
#  (1739, '/m/0lbbj', '1964::Summer::Olympics_PROPN'),
#  (1740,
#   '/m/02g8mp',
#   'Grammy::Award::for::Best::Engineered::Album,::Non-Classical_PROPN'),
#  (1741, '/m/05pdbs', 'Al::Schmitt_PROPN'),
#  (1742, '/m/0n5kc', 'Atlantic::County,::New::Jersey_PROPN'),
#  (1743, '/m/0435vm', 'The::Island::(2005::film)_PROPN'),
#  (1747, '/m/02lq5w', 'Silver::medal_PROPN'),
#  (1749, '/m/0gr0m', 'Academy::Award::for::Best::Cinematography_PROPN'),
#  (1750,
#   '/m/027gs1_',
#   'Primetime::Emmy::Award::for::Outstanding::Directing::for::a::Comedy::Series_PROPN'),
#  (1752, '/m/02pxmgz', 'The::Happening::(2008::film)_PROPN'),
#  (1753, '/m/01k5t_3', 'Chris::Thomas::King_PROPN'),
#  (1754, '/m/0fvvz', 'Baton::Rouge,::Louisiana_PROPN'),
#  (1756, '/m/0tgcy', 'Covington,::Kentucky_PROPN'),
#  (1759, '/m/02c6d', 'Dressed::to::Kill::(1980::film)_PROPN'),
#  (1760, '/m/0bs5f0b', 'Life::as::We::Know::It::(film)_PROPN'),
#  (1761, '/m/0372j5', 'Dumb::and::Dumber_PROPN'),
#  (1763,
#   '/m/02z0dfh',
#   'National::Society::of::Film::Critics::Award::for::Best::Supporting::Actress_PROPN'),
#  (1764, '/m/0hv1t', 'All::That::Jazz_PROPN'),
#  (1770, '/m/0h1wg', 'Leucine_PROPN'),
#  (1772, '/m/01f1jf', '1964::Winter::Olympics_PROPN'),
#  (1774, '/m/05jbn', 'Nashville,::Tennessee_PROPN'),
#  (1776, '/m/03b12', 'Gary,::Indiana_PROPN'),
#  (1777, '/m/020mfr', 'Video::game::industry_PROPN'),
#  (1779, '/m/04hwbq', 'Toy::Story::3_PROPN'),
#  (1781, '/m/0g5pv3', 'For::Your::Eyes::Only::(film)_PROPN'),
#  (1782, '/m/027r9t', 'Almost::Famous_PROPN'),
#  (1783, '/m/034np8', 'Jason::Lee::(actor)_PROPN'),
#  (1784, '/m/0dgst_d', 'My::Week::with::Marilyn_PROPN'),
#  (1786, '/m/05c1t6z', '61st::Primetime::Emmy::Awards_PROPN'),
#  (1791, '/m/0bm02', 'Bass::drum_PROPN'),
#  (1794, '/m/01v0sx2', 'USA::for::Africa_PROPN'),
#  (1796, '/m/01bb9r', 'Three::Kings::(1999::film)_PROPN'),
#  (1802, '/m/0bkj86', 'Master::of::Arts::(postgraduate)_PROPN'),
#  (1804, '/m/0swbd', '1998::Winter::Olympics_PROPN'),
#  (1807, '/m/0cj2nl', 'Lee::Eisenberg_PROPN'),
#  (1808, '/m/0cp0ph6', 'Bad::Teacher_PROPN'),
#  (1810, '/m/04wtx1', 'Megan::McTavish_PROPN'),
#  (1811, '/m/01wdqrx', 'Steve::Jordan::(musician)_PROPN'),
#  (1812, '/m/0cnztc4', "The::Devil's::Double_PROPN"),
#  (1814,
#   '/m/09sdmz',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Male::Actor::in::a::Supporting::Role_PROPN'),
#  (1817, '/m/0cdf37', 'Dean::Tavoularis_PROPN'),
#  (1819, '/m/06mmb', 'Shannon::Elizabeth_PROPN'),
#  (1820, '/m/043q4d', 'Contestant_PROPN'),
#  (1821, '/m/09lxv9', 'Mars::Attacks!_PROPN'),
#  (1823, '/m/02662b', 'Nebula::Award::for::Best::Novelette_PROPN'),
#  (1828, '/m/01718w', 'Training::Day_PROPN'),
#  (1829, '/m/07g_0c', 'The::Weather::Man_PROPN'),
#  (1830, '/m/02vl_pz', 'Giuseppe::Colucci::(footballer)_PROPN'),
#  (1832, '/m/03s5lz', 'Analyze::This_PROPN'),
#  (1835, '/m/01f2xy', 'Sidney::Sussex::College,::Cambridge_PROPN'),
#  (1836, '/m/014mlp', 'Bachelor::of::Arts_PROPN'),
#  (1837, '/m/032_wv', 'Election::(1999::film)_PROPN'),
#  (1839, '/m/0g5879y', 'Albert::Nobbs_PROPN'),
#  (1840,
#   '/m/09td7p',
#   'Screen::Actors::Guild::Award::for::Outstanding::Performance::by::a::Female::Actor::in::a::Supporting::Role_PROPN'),
#  (1841, '/m/0d1mp3', 'Gary::David::Goldberg_PROPN'),
#  (1842, '/m/01j67j', 'Northern::Exposure_PROPN'),
#  (1844, '/m/011ywj', 'Gosford::Park_PROPN'),
#  (1846, '/m/0325pb', 'Alpha::Delta::Pi_PROPN'),
#  (1848, '/m/0mnrb', 'Henrico::County,::Virginia_PROPN'),
#  (1849, '/m/0b7xl8', 'Emanuel::Azenberg_PROPN'),
#  (1852, '/m/05k2s_', 'Tom::Noonan_PROPN'),
#  (1854, '/m/07ddz9', 'Paul::Dooley_PROPN'),
#  (1855, '/m/0m7fm', 'Armstrong::County,::Pennsylvania_PROPN'),
#  (1857, '/m/08lb68', 'Palmitoleic::acid_PROPN'),
#  (1858, '/m/059x0w', 'Tom::Rosenberg_PROPN'),
#  (1859, '/m/02mjs7', 'Law::degree_PROPN'),
#  (1861, '/m/054ks3', 'Golden::Globe::Award::for::Best::Original::Song_PROPN'),
#  (1863, '/m/04mzf8', 'Rebecca::(1940::film)_PROPN'),
#  (1864, '/m/05fg2', 'Norman::Foster,::Baron::Foster::of::Thames::Bank_PROPN'),
#  (1866, '/m/03hbzj', 'John::Romita,::Jr._PROPN'),
#  (1867, '/m/035qlx', 'Cyprus::national::football::team_PROPN'),
#  (1868, '/m/02qdzd', 'Club::Brugge::K.V._PROPN'),
#  (1870, '/m/069q4f', 'Stop!::Or::My::Mom::Will::Shoot_PROPN'),
#  (1871, '/m/07cbcy', 'Golden::Raspberry::Award::for::Worst::Actor_PROPN'),
#  (1872, '/m/0bkbm', 'Spy::film_PROPN'),
#  (1873, '/m/0d1qmz', 'You::Only::Live::Twice::(film)_PROPN'),
#  (1874, '/m/033srr', 'National::Treasure::(film)_PROPN'),
#  (1875, '/m/05drq5', 'Robert::Benton_PROPN'),
#  (1876, '/m/04pbhw', 'Superhero::film_PROPN'),
#  ...]

# %%
# Here we compute the similarity b/w all the words that were found in w2v vocab.
# There too many of these. To be exact, it is 7088 choose 2 = 25,116,328.
# So maybe you don't want to collect them all or interrupt the loop. That's why a 
# progress precentage is printed in the output so you can estimate how long it will
# take and keyboard interrupt is handled properly.
#
# Also you might want to consider forcing the threshold to filter out here instead of later.
# If so just set a non-zero value for threshold <1.
threshold = 0.5
h = [] # heads
t = [] # tails
s = [] # score
not_checked = subset.copy()
c=0
tot = len(subset)
try:
    for w1 in subset:
        c += 1
        not_checked.remove(w1)
        for w2 in not_checked:
            cos_val = wiki_w2v.similarity(w1[2],w2[2])
            if cos_val > threshold:
                h.append(w1[1])
                t.append(w2[1])
                s.append(cos_val) 
        print(f'{100*c/tot:.3f} %\r', end="") # Print progress %
except KeyboardInterrupt: # Take care of it bc sometimes {h,t,s}lenghts do not match.
    print('KeyboardInterrupt at ' + f'{100*c/tot:.3f} %')
    if len(h) > len(t):
        print("I popped!")
        h.pop()
    if len(s) < len(h):
        print("I append!")
        s.append(wiki_w2v.similarity(w1[2],w2[2])) 
    if not(len(s) == len(h) == len(t)):
        print("len s,h,t still don't match :(")
    print("h: " + str(len(h)) + " t: " + str(len(t)) + " s: " + str(len(s)) )
# Out:
# KeyboardInterrupt at 1.086 %
# h: 22777 t: 22777 s: 22777

# %%
d = {'head': h, 'tail':t, 'score':s}
sim_df = pd.DataFrame(data=d)
sim_df
# Out:
#            head       tail     score
# 0      /m/027rn   /m/0160w  0.538880
# 1      /m/027rn    /m/0jgd  0.619635
# 2      /m/027rn  /m/0b90_r  0.676415
# 3      /m/027rn   /m/027nb  0.646344
# 4      /m/027rn    /m/0h3y  0.501404
# ...         ...        ...       ...
# 22772  /m/01914  /m/0d05w3  0.680367
# 22773  /m/01914   /m/06f32  0.532584
# 22774  /m/01914   /m/03h64  0.529266
# 22775  /m/01914   /m/049d1  0.505844
# 22776  /m/01914   /m/06wjf  0.729933
#
# [22777 rows x 3 columns]

# %%
# Filter out more [as you wish] and at the end pass the head and tail column 
# inside another df to the append module.
# For example:
filt = sim_df.loc[sim_df['score'] > .85].copy()
filt.drop(columns='score',inplace=True)
filt # pass this out
# Out:
#             head       tail
# 1380   /m/01cwm1  /m/01cwq9
# 5186    /m/07y_7   /m/05r5c
# 5217    /m/07y_7   /m/01xqw
# 12329   /m/08815   /m/01w5m
# 12331   /m/08815   /m/03ksy
# 12365   /m/08815   /m/05zl0
# 12498   /m/08815   /m/01bm_
# 15622    /m/0jgd   /m/07twz
